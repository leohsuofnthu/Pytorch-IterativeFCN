# %% [markdown]
# <a href="https://colab.research.google.com/github/leohsuofnthu/Pytorch-IterativeFCN/blob/master/Main_191015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install SimpleITK
# !pip install medpy
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.6/dist-packages (1.2.3)
# Requirement already satisfied: medpy in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.16.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.3.1)
# Requirement already satisfied: SimpleITK>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.2.3)

# %%
"""
Training and Evaluation
"""


# -*- coding: utf-8 -*-
"""
Created on Thu Sep 19 11:21:22 2019

@author: Gabriel Hsu
"""
from __future__ import print_function, division
import os
import argparse
import time


import numpy as np
from numpy import random
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torch.nn.functional as F

from model import iterativeFCN
from dataset import CSI_Dataset
from metrics import DiceCoeff, ASSD

import SimpleITK as sitk

def seg_loss(pred, target, weight):
    FP = torch.sum(weight*(1-target)*pred)
    FN = torch.sum(weight*(1-pred)*target)
    return FP, FN
    
#%%
def train_single(args, model, device, img_patch, ins_patch, gt_patch, weight, c_label, optimizer):

    torch.cuda.empty_cache()
  
    model.train()
    correct = 0
    
    img_patch = img_patch.float()
    ins_patch = ins_patch.float()
    gt_patch = gt_patch.float()
    weight = weight.float()
    c_label = c_label.float()
    
    
    #pick a random scan
    optimizer.zero_grad()
    
    #concatenate the img_patch and ins_patch
    input_patch = torch.cat((img_patch, ins_patch), dim=1)
    input_patch, gt_patch, weight, c_label = input_patch.to(device), gt_patch.to(device), weight.to(device), c_label.to(device)
    
    
    S, C = model(input_patch.float())        
    
    
    #Calculate DiceCoeff
    pred = torch.round(S).detach()
    train_dice_coef =  DiceCoeff(pred, gt_patch.detach())
    
    print( train_dice_coef*100, '%')
    
    #compute the loss
    lamda = 0.1
    
    #segloss 
    FP, FN = seg_loss(S, gt_patch, weight) 
 
    s_loss = lamda*FP + FN
    
    c_loss = F.binary_cross_entropy(torch.unsqueeze(C, dim=0), c_label)

    print(s_loss.item(), c_loss.item())
    
    train_loss = s_loss + c_loss
    
    
    
    if C.round() == c_label:
        correct = 1
    
    #optimize the parameters
    train_loss.backward()
    optimizer.step()

    return train_loss.item(), correct, train_dice_coef

def test_single(args, model, device, img_patch, ins_patch, gt_patch, weight, c_label):
    
    torch.cuda.empty_cache()
    
    model.eval()
    correct = 0
    
    img_patch = img_patch.float()
    ins_patch = ins_patch.float()
    gt_patch = gt_patch.float()
    weight = weight.float()
    c_label = c_label.float()
    
    input_patch = torch.cat((img_patch, ins_patch), dim=1)
    input_patch, gt_patch, weight, c_label = input_patch.to(device), gt_patch.to(device), weight.to(device), c_label.to(device)
    
    with torch.no_grad():
        S, C = model(input_patch.float())
        
    """
    pred = torch.squeeze(S.to('cpu'))
    sitk.WriteImage(sitk.GetImageFromArray(pred.numpy()), './pred.nrrd', True)
    
    gtt = torch.squeeze(gt_patch.to('cpu'))
    sitk.WriteImage(sitk.GetImageFromArray(gtt.numpy()), './gt.nrrd', True)
    """
    
    #Calculate DiceCoeff
    pred = torch.round(S).detach()
    test_dice_coef =  DiceCoeff(pred, gt_patch.detach())  
    
    print( test_dice_coef*100, '%')
    
    #compute the loss
    lamda = 0.1
    
    #segloss 
    FP, FN = seg_loss(S, gt_patch, weight) 
    
    s_loss = lamda*FP + FN
    
    c_loss = F.binary_cross_entropy(torch.unsqueeze(C, dim=0), c_label)
    
    
    print(s_loss.item(), c_loss.item())
    
    if C.round() == c_label:
        correct = 1

    test_loss = s_loss + c_loss
    
        
    return test_loss.item(), correct, test_dice_coef
    
#%%Main
if  __name__ == "__main__" :   
    # Version of Pytorch
    print("Pytorch Version:", torch.__version__)
    
    # Training args
    parser = argparse.ArgumentParser(description='Fully Convolutional Network')
    parser.add_argument('--batch-size', type=int, default=1, metavar='N',
                        help='input batch size for training (default: 64)')
    parser.add_argument('--test-batch-size', type=int, default=1, metavar='N',
                        help='input batch size for testing (default: 1000)')
    parser.add_argument('--epochs', type=int, default=100, metavar='N',
                        help='number of epochs to train (default: 10)')
    parser.add_argument('--lr', type=float, default=0.001, metavar='LR',
                        help='learning rate (default: 0.01)')
    parser.add_argument('--momentum', type=float, default=0.99, metavar='M',
                        help='SGD momentum (default: 0.5)')
    parser.add_argument('--no-cuda', action='store_true', default=True,
                        help='disables CUDA training')
    parser.add_argument('--seed', type=int, default=1, metavar='S',
                        help='random seed (default: 1)')
    parser.add_argument('--log-interval', type=int, default=1000, metavar='N',
                        help='how many batches to wait before logging training status')
    
    parser.add_argument('--save-model', action='store_true', default=True,
                        help='For Saving the current Model')
    
    args = parser.parse_known_args()[0]
    #args = parser.parse_args()

    # Use GPU if it is available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    #data_root = './drive/My Drive/patches'
    
    
    # Create FCN
    model = iterativeFCN().to('cuda')
    model.load_state_dict(torch.load('./drive/My Drive/IterativeFCN_best.pth'))
     
    data_root = './drive/My Drive/crop_isotropic_dataset'
    
    batch_size = args.batch_size
    batch_size_valid = batch_size

    
    train_dataset = CSI_Dataset(data_root, subset='train')
    test_dataset = CSI_Dataset(data_root, subset='test')
  
    train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=1 , shuffle=True)
    
    #optimizer
    optimizer = optim.Adam(model.parameters(), lr=args.lr)
    
    train_loss = []
    test_loss = []
    train_acc = []
    test_acc = []
    train_dice = []
    test_dice = []
    best_test_dice = 0
    
    total_iteration = 20000
    train_interval = 50
    eval_interval =  10
    
    # Start Training
    for epoch in range(int(total_iteration/train_interval)):
        
        start_time = time.time()
        epoch_train_dice = []
        epoch_test_dice = []
        epoch_train_loss = []
        epoch_test_loss = []
        epoch_train_accuracy = 0.
        epoch_test_accuracy = 0.
        correct_train_count = 0
        correct_test_count = 0
        
        #training process
        for i in range(train_interval):
            img_patch, ins_patch, gt_patch, weight, c_label = next(iter(train_loader))
            t_loss, t_c, t_dice = train_single(args, model, device, img_patch, ins_patch, gt_patch, weight, c_label, optimizer)
            epoch_train_loss.append(t_loss)
            epoch_train_dice.append(t_dice)
            correct_train_count+=t_c
            
        epoch_train_accuracy = correct_train_count/train_interval
        avg_train_loss = sum(epoch_train_loss) / len(epoch_train_loss)
        avg_train_dice = sum(epoch_train_dice) / len(epoch_train_dice)
        
        print('Train Epoch: {} \t Loss: {:.6f}\t acc: {:.6f}%\t dice: {:.6f}%'.format(epoch
              , avg_train_loss
              , epoch_train_accuracy*100
              , avg_train_dice*100))

        torch.save(model.state_dict(),'./drive/My Drive/IterativeFCN_best_train.pth')
        
        #validation process
        for i in range(eval_interval):
            img_patch, ins_patch, gt_patch, weight, c_label = next(iter(test_loader))
            v_loss, v_c, v_dice = test_single(args, model, device, img_patch, ins_patch, gt_patch, weight, c_label)
            epoch_test_loss.append(v_loss)
            epoch_test_dice.append(v_dice)
            correct_test_count+=v_c
            
        epoch_test_accuracy = correct_test_count/eval_interval
        avg_test_loss = sum(epoch_test_loss) / len(epoch_test_loss)
        avg_test_dice = sum(epoch_test_dice) / len(epoch_test_dice)
        
        
        print('Validation Epoch: {} \t Loss: {:.6f}\t acc: {:.6f}%\t dice: {:.6f}%'.format(epoch
              , avg_test_loss
              , epoch_test_accuracy*100
              , avg_test_dice*100))
        
        if avg_test_dice > best_test_dice:
            best_test_dice = avg_test_dice
            print('--- Saving model at Avg Test Dice:{:.2f}%  ---'.format(avg_test_dice))
            torch.save(model.state_dict(),'./drive/My Drive/IterativeFCN_best.pth')
        
        print('-------------------------------------------------------')
        
        train_loss.append(epoch_train_loss)
        test_loss.append(epoch_test_loss)
        train_acc.append(epoch_train_accuracy)
        test_acc.append(epoch_test_accuracy)
        

        print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 1.0
# Pytorch Version: 1.2.0
# num_channel 64
# elastic deform
# gaussian blur
# 25.704956960522413 %
# 234910.890625 0.7319480180740356
# gaussian noise
# 14.66438009299756 %
# 220824.09375 0.4551393985748291
# gaussian noise
# Random crop along z-axis
# rotate
# 23.695403330789603 %
# 250384.28125 0.8080510497093201
# Random crop along z-axis
# rotate
# 85.67646877645618 %
# 214356.421875 1.182563304901123
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 22.053842662104124 %
# 248460.15625 0.40255945920944214
# gaussian blur
# gaussian noise
# rotate
# 88.24529046924518 %
# 148365.046875 0.809773862361908
# gaussian blur
# gaussian noise
# Random crop along z-axis
# rotate
# 30.171704025754266 %
# 234686.359375 1.0218230485916138
# elastic deform
# gaussian noise
# Random crop along z-axis
# 12.468848742242612 %
# 192977.5 0.5215306282043457
# elastic deform
# gaussian noise
# 17.31405394942901 %
# 193171.5625 0.5964938402175903
# gaussian blur
# rotate
# 19.055188893657327 %
# 209486.265625 0.385098397731781
# rotate
# 6.409040782462613 %
# 193196.484375 0.6306810975074768
# elastic deform
# gaussian noise
# rotate
# 80.94152137418838 %
# 156487.828125 0.7003834247589111
# elastic deform
# Random crop along z-axis
# 13.53621050940765 %
# 182448.703125 0.4916713833808899
# elastic deform
# gaussian blur
# gaussian noise
# 11.805412804173278 %
# 197663.5 0.9599469304084778
# Random crop along z-axis
# rotate
# 32.39576115019051 %
# 153521.953125 1.0264068841934204
# elastic deform
# gaussian noise
# rotate
# 5.59481679334654 %
# 180570.765625 0.5958964824676514
# elastic deform
# Random crop along z-axis
# 0.022126024630170008 %
# 223907.734375 0.7952080368995667
# elastic deform
# Random crop along z-axis
# rotate
# 70.23300984691141 %
# 150016.9375 0.7006222009658813
# elastic deform
# gaussian blur
# 1.3445911695280617 %
# 292292.3125 0.6538676023483276
# gaussian blur
# 4.770162081201077 %
# 251714.328125 0.7212782502174377
# elastic deform
# gaussian blur
# Random crop along z-axis
# 4.515758049220963 %
# 255165.578125 0.8194880485534668
# gaussian blur
# gaussian noise
# 2.037996054778251 %
# 173739.1875 0.729552149772644
# gaussian blur
# Random crop along z-axis
# rotate
# 38.56044191993129 %
# 172061.671875 0.8065986633300781
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 84.73342482905014 %
# 143595.53125 0.7561948895454407
# Random crop along z-axis
# rotate
# 30.668602656404826 %
# 211671.296875 0.8323234915733337
# elastic deform
# 3.8510299348329204 %
# 179858.75 0.5536400675773621
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 0.21290611093420028 %
# 216750.125 0.9897950887680054
# elastic deform
# rotate
# 4.932154705732235 %
# 204503.171875 0.764864444732666
# elastic deform
# gaussian blur
# Random crop along z-axis
# 6.41881922285823 %
# 167908.125 0.44789960980415344
# elastic deform
# gaussian blur
# gaussian noise
# 71.61733597426166 %
# 151226.859375 0.55258709192276
# gaussian blur
# Random crop along z-axis
# rotate
# 32.54508199011313 %
# 206395.890625 0.6472646594047546
# Random crop along z-axis
# rotate
# 15.33876283019851 %
# 301795.59375 0.80718994140625
# gaussian blur
# rotate
# 0.49658925829317874 %
# 205239.953125 0.589843213558197
# gaussian noise
# Random crop along z-axis
# rotate
# 20.827208908539312 %
# 361834.0 0.5408527255058289
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 18.83378275867797 %
# 245208.6875 0.9282832741737366
# gaussian blur
# gaussian noise
# rotate
# 67.57281467568268 %
# 145085.71875 0.7039164900779724
# Random crop along z-axis
# 17.489868566374643 %
# 237116.734375 0.5846725106239319
# Random crop along z-axis
# rotate
# 25.548996093885563 %
# 274847.3125 0.6842653751373291
# elastic deform
# Random crop along z-axis
# rotate
# 23.891584153415728 %
# 241424.5 0.8593569993972778
# gaussian blur
# rotate
# 12.104020063795076 %
# 197302.421875 0.5220487117767334
# gaussian noise
# Random crop along z-axis
# 0.9424662078741166 %
# 250354.75 0.6153825521469116
# gaussian blur
# Random crop along z-axis
# 81.11750515644499 %
# 166914.3125 0.5162697434425354
# Random crop along z-axis
# 8.363093701751833 %
# 190433.84375 1.0290353298187256
# gaussian noise
# 8.492744026181418 %
# 185114.875 0.6870172023773193
# elastic deform
# gaussian blur
# 8.448367307918737 %
# 216279.703125 0.6788164973258972
# gaussian blur
# 19.597747385358005 %
# 204312.546875 0.9177969694137573
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 12.07861634378321 %
# 199646.765625 0.9462560415267944
# gaussian noise
# Random crop along z-axis
# rotate
# 85.15297724939686 %
# 157671.28125 0.5424214005470276
# gaussian blur
# gaussian noise
# 9.759628942173736 %
# 204766.953125 0.5922462344169617
# gaussian blur
# rotate
# 25.849800301712587 %
# 226968.59375 0.636926531791687
# Train Epoch: 0 	 Loss: 208493.465938	 acc: 50.000000%	 dice: 26.162058%
# elastic deform
# gaussian noise
# Random crop along z-axis
# 0.2859124396024324 %
# 283891.875 0.0018856411334127188
# elastic deform
# gaussian noise
# Random crop along z-axis
# 1.1001735609662169 %
# 420541.6875 0.00021418242249637842
# elastic deform
# gaussian blur
# gaussian noise
# 0.32532104342724827 %
# 252911.375 0.016225550323724747
# elastic deform
# gaussian noise
# 0.08495083148844154 %
# 270269.5 0.00011516280210344121
# gaussian blur
# gaussian noise
# 0.14369965095522527 %
# 242610.703125 0.003603386227041483
# gaussian noise
# Random crop along z-axis
# 77.84885109357253 %
# 112383.3046875 27.63102149963379
# elastic deform
# Random crop along z-axis
# 1.5949314037207305 %
# 542058.625 0.0004996117204427719
# elastic deform
# gaussian noise
# Random crop along z-axis
# 0.2902243806005331 %
# 123582.59375 7.960651874542236
# gaussian blur
# gaussian noise
# Random crop along z-axis
# rotate
# 10.286016063707724 %
# 122677.1953125 7.4200053215026855
# Random crop along z-axis
# 1.3202593366554145 %
# 432101.6875 0.00037092887214384973
# Validation Epoch: 0 	 Loss: 280307.157813	 acc: 70.000000%	 dice: 9.328034%
# --- Saving model at Avg Test Dice:0.09%  ---
# -------------------------------------------------------
# --- 995.1848731040955 seconds ---
# elastic deform
# Random crop along z-axis
# 9.213585562788673 %
# 229681.5 0.43216967582702637
# elastic deform
# gaussian blur
# rotate
# 10.870600965809068 %
# 174613.65625 0.6635549664497375
# gaussian blur
# 24.01555094199189 %
# 265340.25 0.6028851866722107
# elastic deform
# gaussian blur
# Random crop along z-axis
# 82.4209657882144 %
# 151110.875 0.4376145601272583
# rotate
# 8.84624525826657 %
# 190784.796875 0.724005401134491
# elastic deform
# gaussian noise
# rotate
# 10.246549701377013 %
# 214712.3125 0.23303307592868805
# gaussian noise
# rotate
# 9.20110820144977 %
# 195558.09375 0.8211848139762878
# gaussian noise
# 3.575592693354061 %
# 204238.9375 0.638624906539917
# gaussian blur
# gaussian noise
# 11.740657641532424 %
# 188357.8125 0.3743363320827484
# elastic deform
# gaussian noise
# rotate
# 89.27207606673501 %
# 155264.890625 1.2760279178619385
# elastic deform
# gaussian blur
# Random crop along z-axis
# rotate
# 25.858716785482827 %
# 320520.25 0.94376140832901
# elastic deform
# gaussian noise
# rotate
# 25.745026568881475 %
# 182976.53125 0.3517493009567261
# gaussian noise
# Random crop along z-axis
# 13.112317677020396 %
# 190188.53125 0.5231797695159912
# gaussian blur
# Random crop along z-axis
# rotate
# 30.491199736976643 %
# 180898.734375 1.044665813446045
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 44.99031996169619 %
# 275197.75 0.4863605797290802
# elastic deform
# gaussian blur
# gaussian noise
# rotate
# 89.84831736722418 %
# 136480.296875 1.164804458618164
# elastic deform
# gaussian blur
# Random crop along z-axis
# rotate
# 29.165010360722288 %
# 280388.375 0.8808623552322388
# gaussian blur
# gaussian noise
# 8.876168568027712 %
# 167911.984375 0.5061833262443542
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# rotate
# 28.620232182329612 %
# 177881.03125 1.4542523622512817
# Random crop along z-axis
# 94.44988570007821 %
# 226158.046875 1.2419161796569824
# elastic deform
# gaussian noise
# Random crop along z-axis
# 13.95005449240036 %
# 184383.421875 0.8025987148284912
# elastic deform
# gaussian blur
# Random crop along z-axis
# rotate
# 62.54078578760321 %
# 134477.28125 1.0771733522415161
# elastic deform
# gaussian blur
# gaussian noise
# 15.248801576783643 %
# 205926.953125 0.5941933393478394
# gaussian blur
# Random crop along z-axis
# 33.092057090040456 %
# 218026.671875 0.38810232281684875
# elastic deform
# gaussian noise
# Random crop along z-axis
# 6.629653327421947 %
# 196849.46875 0.39241793751716614
# Random crop along z-axis
# rotate
# 34.89285900659926 %
# 196473.84375 0.7615867257118225
# 36.01427209771157 %
# 263553.8125 0.38846060633659363
# elastic deform
# gaussian blur
# Random crop along z-axis
# rotate
# 81.0588455150326 %
# 136752.15625 0.4563089609146118
# elastic deform
# gaussian blur
# gaussian noise
# rotate
# 29.74131147071869 %
# 227393.8125 1.3060767650604248
# elastic deform
# Random crop along z-axis
# 47.409594683780526 %
# 206277.5 0.2858952283859253
# 10.852900709112626 %
# 320884.8125 0.6199276447296143
# elastic deform
# gaussian blur
# gaussian noise
# rotate
# 8.660943576197813 %
# 194497.171875 0.31508761644363403
# gaussian noise
# Random crop along z-axis
# 33.76109085649591 %
# 191163.75 0.8457614183425903
# elastic deform
# gaussian noise
# Random crop along z-axis
# 90.34419075486043 %
# 155290.53125 0.7058593034744263
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 30.027937882258186 %
# 216029.8125 0.4415534436702728
# elastic deform
# rotate
# 13.795028326424932 %
# 185624.21875 0.3670324385166168
# elastic deform
# gaussian noise
# Random crop along z-axis
# 6.080374378473238 %
# 237702.28125 0.6225153207778931
# elastic deform
# 18.59358166751871 %
# 189101.515625 0.6969175338745117
# gaussian blur
# Random crop along z-axis
# rotate
# 92.48682456679997 %
# 198601.296875 1.0679993629455566
# Random crop along z-axis
# 85.61582848744852 %
# 155145.234375 0.8644875288009644
# gaussian blur
# gaussian noise
# 7.012138167074501 %
# 198684.765625 0.5974137783050537
# gaussian blur
# gaussian noise
# 11.384533102710575 %
# 177284.171875 0.4236701428890228
# elastic deform
# gaussian noise
# 29.588583103736493 %
# 221761.71875 0.829417884349823
# gaussian noise
# rotate
# 13.126446973055513 %
# 169165.40625 0.6530856490135193
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 31.71698926308647 %
# 177579.375 0.660831868648529
# elastic deform
# gaussian noise
# rotate
# 60.56703284282682 %
# 131089.453125 1.62394380569458
# Random crop along z-axis
# 3.2191169199205922 %
# 246834.65625 1.5811986923217773
# elastic deform
# gaussian blur
# gaussian noise
# 4.668229140894089 %
# 172525.828125 0.29712361097335815
# gaussian blur
# gaussian noise
# 5.452354789782656 %
# 158819.921875 0.47170671820640564
# gaussian noise
# Random crop along z-axis
# 58.55347178170926 %
# 144641.796875 1.5690306425094604
# Train Epoch: 1 	 Loss: 198416.875000	 acc: 56.000000%	 dice: 32.532919%
# elastic deform
# gaussian blur
# Random crop along z-axis
# rotate
# 96.08596541256259 %
# 106981.6796875 11.535665512084961
# elastic deform
# gaussian blur
# Random crop along z-axis
# rotate
# 96.47068116070811 %
# 74006.1796875 27.63102149963379
# elastic deform
# rotate
# 0.14525047921332565 %
# 168520.4375 0.003954111598432064
# elastic deform
# gaussian blur
# gaussian noise
# rotate
# 0.41717783207923703 %
# 227451.328125 0.057332515716552734
# gaussian blur
# gaussian noise
# 8.769381246997678 %
# 254606.109375 0.0004752811510115862
# rotate
# 2.3870866313523296 %
# 200953.28125 0.0035185653250664473
# elastic deform
# gaussian blur
# gaussian noise
# 6.025773427327017 %
# 241628.4375 0.0016800560988485813
# elastic deform
# rotate
# 87.38551421943465 %
# 87515.84375 27.63102149963379
# gaussian noise
# Random crop along z-axis
# rotate
# 26.60842808326276 %
# 258553.265625 4.464144229888916
# 0.5408223245277191 %
# 225698.546875 0.010518844239413738
# Validation Epoch: 1 	 Loss: 184598.646094	 acc: 60.000000%	 dice: 32.483608%
# --- Saving model at Avg Test Dice:0.32%  ---
# -------------------------------------------------------
# --- 977.137293100357 seconds ---
# elastic deform
# gaussian blur
# Random crop along z-axis
# 4.864708624329039 %
# 185481.125 0.2991649806499481
# Random crop along z-axis
# rotate
# 55.39351041804933 %
# 125220.6796875 0.8723328113555908
# elastic deform
# gaussian blur
# Random crop along z-axis
# rotate
# 28.092163286645803 %
# 264321.75 0.9924930334091187
# elastic deform
# gaussian blur
# 4.754798307523567 %
# 193044.4375 0.6313890218734741
# elastic deform
# gaussian noise
# 2.175396217672496 %
# 157159.703125 0.439311683177948
# gaussian noise
# 4.843595061382552 %
# 158796.4375 0.49757760763168335
# gaussian blur
# rotate
# 7.506551646244277 %
# 168879.875 0.376627653837204
# gaussian blur
# rotate
# 63.86682375699036 %
# 138251.09375 0.609440803527832
# elastic deform
# gaussian noise
# 4.625311668988491 %
# 158807.078125 0.3624010980129242
# gaussian blur
# gaussian noise
# Random crop along z-axis
# rotate
# 29.64585302457467 %
# 182727.8125 0.7740892171859741
# Random crop along z-axis
# rotate
# 29.483642210545575 %
# 159236.796875 1.0484497547149658
# elastic deform
# gaussian blur
# gaussian noise
# rotate
# 29.185400727155404 %
# 165981.53125 0.28279975056648254
# elastic deform
# gaussian blur
# gaussian noise
# rotate
# 18.992475361199983 %
# 162857.0 0.4870949983596802
# elastic deform
# gaussian noise
# Random crop along z-axis
# rotate
# 92.80668445254994 %
# 121969.1640625 1.105799674987793
# elastic deform
# gaussian noise
# Random crop along z-axis
# rotate
# 94.59646237688105 %
# 198581.125 0.8699851632118225
# gaussian noise
# Random crop along z-axis
# rotate
# 28.435818360087563 %
# 191169.703125 1.0986450910568237
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 77.92720634802369 %
# 127798.6875 1.469301700592041
# elastic deform
# 9.397109788792257 %
# 161775.265625 0.4885883331298828
# elastic deform
# gaussian blur
# 19.394055570128536 %
# 170709.734375 0.39144977927207947
# rotate
# 88.7508882175996 %
# 115418.3046875 1.1603269577026367
# elastic deform
# gaussian blur
# gaussian noise
# 17.444206121085994 %
# 160272.109375 0.41675639152526855
# elastic deform
# gaussian noise
# rotate
# 27.03228908179323 %
# 247092.6875 0.41499724984169006
# gaussian blur
# gaussian noise
# 28.07284707605015 %
# 231338.8125 0.44320622086524963
# elastic deform
# gaussian noise
# Random crop along z-axis
# rotate
# 14.635956016389514 %
# 363984.34375 0.6907691359519958
# gaussian blur
# 0.0 %
# 130094.875 0.3104129135608673
# Random crop along z-axis
# 92.90275565188105 %
# 126547.9921875 0.7648658752441406
# elastic deform
# gaussian blur
# 35.73148180454276 %
# 182425.984375 0.5568849444389343
# gaussian noise
# rotate
# 13.567412959857975 %
# 186903.5625 0.7880927324295044
# elastic deform
# gaussian blur
# gaussian noise
# rotate
# 32.537188420229974 %
# 205439.34375 0.628321647644043
# rotate
# 45.81150018021015 %
# 281755.625 0.7519320845603943
# gaussian blur
# gaussian noise
# 30.570146450064357 %
# 168401.296875 0.7157717943191528
# Random crop along z-axis
# 93.02127941765352 %
# 134089.859375 0.6019599437713623
# elastic deform
# gaussian blur
# gaussian noise
# 11.733934055249527 %
# 190664.484375 0.5432808995246887
# elastic deform
# gaussian blur
# rotate
# 0.0 %
# 161690.53125 0.8083577156066895
# elastic deform
# gaussian blur
# 21.42913074118865 %
# 173201.40625 0.6972703337669373
# elastic deform
# 27.39641679577325 %
# 188242.59375 1.014051079750061
# gaussian blur
# 0.12309611685813796 %
# 202599.203125 0.5999886393547058
# 75.12864330584418 %
# 125069.0390625 0.8915900588035583
# elastic deform
# gaussian noise
# rotate
# 9.43605226279779 %
# 194204.96875 0.5566102266311646
# elastic deform
# gaussian blur
# gaussian noise
# rotate
# 5.5830221365796255 %
# 153470.6875 0.8568650484085083
# elastic deform
# gaussian blur
# Random crop along z-axis
# rotate
# 34.37869884465115 %
# 207495.21875 0.7370744943618774
# Random crop along z-axis
# rotate
# 26.568156958660616 %
# 212123.78125 1.1251732110977173
# gaussian noise
# rotate
# 25.442054188672763 %
# 182636.28125 0.43944525718688965
# elastic deform
# gaussian blur
# 62.796818582388894 %
# 143199.65625 0.7543060183525085
# 15.097813743717603 %
# 179916.734375 0.7746388912200928
# gaussian blur
# gaussian noise
# rotate
# 17.968849227816484 %
# 168548.71875 0.5457873940467834
# elastic deform
# Random crop along z-axis
# rotate
# 27.63342347312538 %
# 268022.5625 0.5827048420906067
# gaussian noise
# Random crop along z-axis
# rotate
# 36.82577139343727 %
# 155763.09375 0.7545009255409241
# Random crop along z-axis
# rotate
# 27.501301426047455 %
# 190513.96875 0.6745237112045288
# elastic deform
# gaussian noise
# rotate
# 80.75603269902264 %
# 128480.3671875 0.8164367079734802
# Train Epoch: 2 	 Loss: 179048.232813	 acc: 52.000000%	 dice: 32.637295%
# elastic deform
# gaussian noise
# Random crop along z-axis
# 1.94439794486151 %
# 239703.90625 4.291543518775143e-06
# 1.6746822563611474 %
# 213073.28125 1.1920930376163597e-07
# Random crop along z-axis
# rotate
# 5.80488940628638 %
# 155415.25 15.942384719848633
# elastic deform
# gaussian noise
# 89.46493203666526 %
# 91693.34375 27.63102149963379
# elastic deform
# 12.427549519244955 %
# 302235.125 0.0
# gaussian blur
# gaussian noise
# 2.798763647958528 %
# 257646.53125 7.152560215217818e-07
# elastic deform
# gaussian noise
# rotate
# 1.185359848580272 %
# 156673.984375 1.0728841743912199e-06
# elastic deform
# 7.030906694009081 %
# 399912.03125 0.0
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 2.2327136676530004 %
# 431706.4375 1.1920930376163597e-07
# elastic deform
# gaussian noise
# Random crop along z-axis
# rotate
# 97.15452038590988 %
# 78557.0859375 27.63102149963379
# Validation Epoch: 2 	 Loss: 232668.817969	 acc: 70.000000%	 dice: 22.171872%
# -------------------------------------------------------
# --- 974.3359065055847 seconds ---
# elastic deform
# 19.866395953235415 %
# 179989.4375 0.5924242734909058
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 32.884626144692916 %
# 234794.15625 0.6252431869506836
# gaussian blur
# 16.501924693597626 %
# 215852.0 0.565096378326416
# gaussian blur
# Random crop along z-axis
# 93.6345365994682 %
# 135823.703125 0.5539044141769409
# gaussian blur
# Random crop along z-axis
# 42.72730310422027 %
# 188164.546875 0.5688900947570801
# gaussian noise
# rotate
# 90.04049907613448 %
# 128025.203125 0.9058560729026794
# elastic deform
# Random crop along z-axis
# rotate
# 24.08461783280165 %
# 158379.453125 1.1161119937896729
# gaussian blur
# Random crop along z-axis
# 24.540804354967385 %
# 233600.390625 0.6233116388320923
# elastic deform
# gaussian blur
# 6.808884721326848 %
# 159313.828125 0.6016166806221008
# elastic deform
# gaussian noise
# 4.295024883287367 %
# 164321.609375 0.7858560085296631
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 16.651403219569776 %
# 148287.1875 0.6629986763000488
# elastic deform
# 92.50892234294088 %
# 126722.1796875 0.7207191586494446
# elastic deform
# 37.263691138657556 %
# 191378.625 0.769465982913971
# gaussian noise
# 24.184659080236084 %
# 168308.59375 0.5222619771957397
# gaussian blur
# rotate
# 18.84609938064112 %
# 160561.90625 0.5217631459236145
# Random crop along z-axis
# rotate
# 10.821434250278264 %
# 157210.046875 0.9143975973129272
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# rotate
# 91.08032231032172 %
# 142673.15625 0.6676532626152039
# gaussian blur
# Random crop along z-axis
# rotate
# 87.12248045576176 %
# 145134.96875 0.8625097274780273
# gaussian blur
# Random crop along z-axis
# 20.89405843815425 %
# 165281.828125 0.3364907503128052
# gaussian blur
# gaussian noise
# Random crop along z-axis
# rotate
# 21.067035702114037 %
# 237914.65625 1.1041693687438965
# elastic deform
# 10.167787764812317 %
# 155052.546875 0.6102097630500793
# gaussian blur
# 16.020301639729016 %
# 227146.5 0.38298299908638
# elastic deform
# 9.195543996984446 %
# 147700.640625 0.42777881026268005
# elastic deform
# gaussian blur
# Random crop along z-axis
# 87.63531542344003 %
# 127356.1875 0.56227046251297
# elastic deform
# gaussian blur
# rotate
# 12.490542281057417 %
# 163755.09375 0.42683959007263184
# gaussian blur
# rotate
# 10.80744006020858 %
# 163524.625 0.6031114459037781
# elastic deform
# gaussian blur
# Random crop along z-axis
# 23.089335705011298 %
# 187305.640625 0.4176813066005707
# gaussian blur
# 7.87733421377174 %
# 304984.3125 0.27483636140823364
# 7.391366780607688 %
# 158585.8125 0.5672206878662109
# gaussian blur
# gaussian noise
# 83.43204113655806 %
# 142410.421875 1.1581426858901978
# Random crop along z-axis
# rotate
# 26.881724073666195 %
# 219156.390625 0.5095743536949158
# elastic deform
# 13.68695652173913 %
# 170680.0 0.6076015830039978
# gaussian noise
# Random crop along z-axis
# 24.444621333112035 %
# 178769.890625 0.2400209605693817
# gaussian blur
# 13.017144186093542 %
# 185731.734375 0.46222150325775146
# elastic deform
# Random crop along z-axis
# rotate
# 18.36139734692504 %
# 167385.15625 0.7832886576652527
# gaussian blur
# Random crop along z-axis
# 89.44730558540577 %
# 131103.109375 1.187568187713623
# elastic deform
# gaussian noise
# Random crop along z-axis
# 40.11583638111168 %
# 173908.84375 0.4686889946460724
# rotate
# 32.30166976929621 %
# 166356.265625 0.4532312750816345
# elastic deform
# gaussian blur
# Random crop along z-axis
# rotate
# 35.73237984011276 %
# 206593.609375 1.1682307720184326

# %%
print("training:", len(train_loss))
print("validation:", len(test_loss))
x = list(range(1, len(train_loss)))
#plot train/validation loss versus epoch
plt.figure()
plt.title("Train/Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Total Loss")
plt.plot(x, train_loss,label="train loss")
plt.plot(x, test_loss, color='red', label="validation loss")
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

#plot train/validation loss versus epoch
plt.figure()
plt.title("Train/Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot(x, train_acc,label="train acc")
plt.plot(x, test_acc, color='red', label="validation acc")
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
