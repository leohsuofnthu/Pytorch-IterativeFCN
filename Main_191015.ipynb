# %% [markdown]
# <a href="https://colab.research.google.com/github/leohsuofnthu/Pytorch-IterativeFCN/blob/master/Main_191015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install SimpleITK
# !pip install medpy
# Out:
# Collecting SimpleITK
#   Downloading https://files.pythonhosted.org/packages/bb/06/f3a67ef0e108d18840fd5e83f831d5ef1710ba46f05465fc50f9a505b518/SimpleITK-1.2.3-cp36-cp36m-manylinux1_x86_64.whl (42.5MB)
#      |████████████████████████████████| 42.5MB 3.9MB/s
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-1.2.3
# Collecting medpy
#   Downloading https://files.pythonhosted.org/packages/3b/70/c1fd5dd60242eee81774696ea7ba4caafac2bad8f028bba94b1af83777d7/MedPy-0.4.0.tar.gz (151kB)
#      |████████████████████████████████| 153kB 6.5MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.3.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.16.5)
# Requirement already satisfied: SimpleITK>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.2.3)
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-cp36-cp36m-linux_x86_64.whl size=753419 sha256=6dab62daef9225581c9b4a97ceaf68a28a29a380643a778736020bc3c70afe2d
#   Stored in directory: /root/.cache/pip/wheels/8c/c9/9c/2c6281c7a72b9fb1570862a4f028af7ce38405008354fbf870
# Successfully built medpy
# Installing collected packages: medpy
# Successfully installed medpy-0.4.0

# %%
"""
Training and Evaluation
"""


# -*- coding: utf-8 -*-
"""
Created on Thu Sep 19 11:21:22 2019

@author: Gabriel Hsu
"""
from __future__ import print_function, division
import os
import argparse
import time


import numpy as np
from numpy import random
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torch.nn.functional as F

from model import iterativeFCN
from dataset import CSI_Dataset
from metrics import DiceCoeff, ASSD

import SimpleITK as sitk

def seg_loss(pred, target, weight):
    FP = torch.sum(weight*(1-target)*pred)
    FN = torch.sum(weight*(1-pred)*target)
    return FP, FN
    
#%%
def train_single(args, model, device, img_patch, ins_patch, gt_patch, weight, c_label, optimizer):

    torch.cuda.empty_cache()
  
    model.train()
    correct = 0
    
    img_patch = img_patch.float()
    ins_patch = ins_patch.float()
    gt_patch = gt_patch.float()
    weight = weight.float()
    c_label = c_label.float()
    
    
    #pick a random scan
    optimizer.zero_grad()
    
    #concatenate the img_patch and ins_patch
    input_patch = torch.cat((img_patch, ins_patch), dim=1)
    input_patch, gt_patch, weight, c_label = input_patch.to(device), gt_patch.to(device), weight.to(device), c_label.to(device)
    
    
    S, C = model(input_patch.float())        
    
    
    #Calculate DiceCoeff
    pred = torch.round(S).detach()
    train_dice_coef =  DiceCoeff(pred, gt_patch.detach())
    
    print( train_dice_coef*100, '%')
    
    #compute the loss
    lamda = 0.1
    
    #segloss 
    FP, FN = seg_loss(S, gt_patch, weight) 
 
    s_loss = lamda*FP + FN
    
    c_loss = F.binary_cross_entropy(torch.unsqueeze(C, dim=0), c_label)

    print(s_loss.item(), c_loss.item())
    
    train_loss = s_loss + c_loss
    
    
    
    if C.round() == c_label:
        correct = 1
    
    #optimize the parameters
    train_loss.backward()
    optimizer.step()

    return train_loss.item(), correct, train_dice_coef

def test_single(args, model, device, img_patch, ins_patch, gt_patch, weight, c_label):
    
    torch.cuda.empty_cache()
    
    model.eval()
    correct = 0
    
    img_patch = img_patch.float()
    ins_patch = ins_patch.float()
    gt_patch = gt_patch.float()
    weight = weight.float()
    c_label = c_label.float()
    
    input_patch = torch.cat((img_patch, ins_patch), dim=1)
    input_patch, gt_patch, weight, c_label = input_patch.to(device), gt_patch.to(device), weight.to(device), c_label.to(device)
    
    with torch.no_grad():
        S, C = model(input_patch.float())
        
    """
    pred = torch.squeeze(S.to('cpu'))
    sitk.WriteImage(sitk.GetImageFromArray(pred.numpy()), './pred.nrrd', True)
    
    gtt = torch.squeeze(gt_patch.to('cpu'))
    sitk.WriteImage(sitk.GetImageFromArray(gtt.numpy()), './gt.nrrd', True)
    """
    
    #Calculate DiceCoeff
    pred = torch.round(S).detach()
    test_dice_coef =  DiceCoeff(pred, gt_patch.detach())  
    
    print( test_dice_coef*100, '%')
    
    #compute the loss
    lamda = 0.1
    
    #segloss 
    FP, FN = seg_loss(S, gt_patch, weight) 
    
    s_loss = lamda*FP + FN
    
    c_loss = F.binary_cross_entropy(torch.unsqueeze(C, dim=0), c_label)
    
    
    print(s_loss.item(), c_loss.item())
    
    if C.round() == c_label:
        correct = 1

    test_loss = s_loss + c_loss
    
        
    return test_loss.item(), correct, test_dice_coef
    
#%%Main
if  __name__ == "__main__" :   
    # Version of Pytorch
    print("Pytorch Version:", torch.__version__)
    
    # Training args
    parser = argparse.ArgumentParser(description='Fully Convolutional Network')
    parser.add_argument('--batch-size', type=int, default=1, metavar='N',
                        help='input batch size for training (default: 64)')
    parser.add_argument('--test-batch-size', type=int, default=1, metavar='N',
                        help='input batch size for testing (default: 1000)')
    parser.add_argument('--epochs', type=int, default=100, metavar='N',
                        help='number of epochs to train (default: 10)')
    parser.add_argument('--lr', type=float, default=0.001, metavar='LR',
                        help='learning rate (default: 0.01)')
    parser.add_argument('--momentum', type=float, default=0.99, metavar='M',
                        help='SGD momentum (default: 0.5)')
    parser.add_argument('--no-cuda', action='store_true', default=True,
                        help='disables CUDA training')
    parser.add_argument('--seed', type=int, default=1, metavar='S',
                        help='random seed (default: 1)')
    parser.add_argument('--log-interval', type=int, default=1000, metavar='N',
                        help='how many batches to wait before logging training status')
    
    parser.add_argument('--save-model', action='store_true', default=True,
                        help='For Saving the current Model')
    
    args = parser.parse_known_args()[0]
    #args = parser.parse_args()

    # Use GPU if it is available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    #data_root = './drive/My Drive/patches'
    
    
    # Create FCN
    model = iterativeFCN().to('cuda')
    model.load_state_dict(torch.load('./drive/My Drive/IterativeFCN_best_train.pth'))
     
    data_root = './drive/My Drive/crop_isotropic_dataset'
    
    batch_size = args.batch_size
    batch_size_valid = batch_size

    
    train_dataset = CSI_Dataset(data_root, subset='train')
    test_dataset = CSI_Dataset(data_root, subset='test')
  
    train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=1 , shuffle=True)
    
    #optimizer
    optimizer = optim.Adam(model.parameters(), lr=args.lr)
    
    train_loss = []
    test_loss = []
    train_acc = []
    test_acc = []
    train_dice = []
    test_dice = []
    best_test_dice = 0
    
    total_iteration = 20000
    train_interval = 50
    eval_interval =  10
    
    # Start Training
    for epoch in range(int(total_iteration/train_interval)):
        
        start_time = time.time()
        epoch_train_dice = []
        epoch_test_dice = []
        epoch_train_loss = []
        epoch_test_loss = []
        epoch_train_accuracy = 0.
        epoch_test_accuracy = 0.
        correct_train_count = 0
        correct_test_count = 0
        
        #training process
        for i in range(train_interval):
            img_patch, ins_patch, gt_patch, weight, c_label = next(iter(train_loader))
            t_loss, t_c, t_dice = train_single(args, model, device, img_patch, ins_patch, gt_patch, weight, c_label, optimizer)
            epoch_train_loss.append(t_loss)
            epoch_train_dice.append(t_dice)
            correct_train_count+=t_c
            
        epoch_train_accuracy = correct_train_count/train_interval
        avg_train_loss = sum(epoch_train_loss) / len(epoch_train_loss)
        avg_train_dice = sum(epoch_train_dice) / len(epoch_train_dice)
        
        print('Train Epoch: {} \t Loss: {:.6f}\t acc: {:.6f}%\t dice: {:.6f}%'.format(epoch
              , avg_train_loss
              , epoch_train_accuracy*100
              , avg_train_dice*100))

        torch.save(model.state_dict(),'./drive/My Drive/IterativeFCN_best_train.pth')
        
        #validation process
        for i in range(eval_interval):
            img_patch, ins_patch, gt_patch, weight, c_label = next(iter(test_loader))
            v_loss, v_c, v_dice = test_single(args, model, device, img_patch, ins_patch, gt_patch, weight, c_label)
            epoch_test_loss.append(v_loss)
            epoch_test_dice.append(v_dice)
            correct_test_count+=v_c
            
        epoch_test_accuracy = correct_test_count/eval_interval
        avg_test_loss = sum(epoch_test_loss) / len(epoch_test_loss)
        avg_test_dice = sum(epoch_test_dice) / len(epoch_test_dice)
        
        
        print('Validation Epoch: {} \t Loss: {:.6f}\t acc: {:.6f}%\t dice: {:.6f}%'.format(epoch
              , avg_test_loss
              , epoch_test_accuracy*100
              , avg_test_dice*100))
        
        if avg_test_dice > best_test_dice:
            best_test_dice = avg_test_dice
            print('--- Saving model at Avg Test Dice:{:.2f}%  ---'.format(avg_test_dice))
            torch.save(model.state_dict(),'./drive/My Drive/IterativeFCN_best.pth')
        
        print('-------------------------------------------------------')
        
        train_loss.append(epoch_train_loss)
        test_loss.append(epoch_test_loss)
        train_acc.append(epoch_train_accuracy)
        test_acc.append(epoch_test_accuracy)
        

        print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 1.0
# Pytorch Version: 1.2.0
# num_channel 64
# elastic deform
# Random crop along z-axis
# 98.73634826377052 %
# 20824.416015625 0.5616318583488464
# 65.34188657238664 %
# 29076.189453125 0.6092438101768494
# 69.23624494331303 %
# 31320.388671875 0.47485995292663574
# elastic deform
# gaussian noise
# Random crop along z-axis
# 0.7914595987483894 %
# 72099.0859375 0.38111403584480286
# gaussian blur
# Random crop along z-axis
# 76.198537899192 %
# 60809.203125 0.8489010334014893
# gaussian blur
# gaussian noise
# 99.7622094115364 %
# 20371.865234375 0.5209661722183228
# elastic deform
# gaussian noise
# 85.13940094942046 %
# 25877.41015625 0.5891794562339783
# elastic deform
# gaussian noise
# Random crop along z-axis
# 91.45378382090372 %
# 45337.609375 1.2166926860809326
# elastic deform
# 81.95824512061319 %
# 31899.01171875 0.5668050050735474
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 69.50641889438478 %
# 61683.3515625 0.6296041011810303
# elastic deform
# gaussian noise
# Random crop along z-axis
# 82.47264186195484 %
# 33466.80859375 0.8842068314552307
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 99.28866066268253 %
# 20704.02734375 0.8041365742683411
# elastic deform
# Random crop along z-axis
# 81.0819543885308 %
# 27929.25390625 0.43537700176239014
# elastic deform
# gaussian blur
# Random crop along z-axis
# 72.6938723799603 %
# 34269.95703125 0.7300613522529602
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 84.95823973273428 %
# 47716.21875 0.44693225622177124
# gaussian noise
# 83.0358342549431 %
# 25397.841796875 0.5139788389205933
# Random crop along z-axis
# 74.53464037889636 %
# 29926.92578125 0.5879014134407043
# gaussian noise
# Random crop along z-axis
# 98.39857332286225 %
# 24204.171875 0.7238572239875793
# gaussian blur
# gaussian noise
# 65.02004618779029 %
# 36688.0546875 0.4361101984977722
# elastic deform
# gaussian blur
# gaussian noise
# 60.85907948516158 %
# 31629.466796875 0.5892749428749084
# elastic deform
# gaussian noise
# 71.05465056113619 %
# 29574.396484375 0.6068894267082214
# elastic deform
# gaussian blur
# gaussian noise
# 67.20831341984976 %
# 36985.734375 0.9650371074676514
# elastic deform
# gaussian blur
# Random crop along z-axis
# 60.35502958579882 %
# 34064.6796875 0.5293223261833191
# elastic deform
# gaussian blur
# 98.98372079524925 %
# 22482.5625 0.7825522422790527
# elastic deform
# gaussian noise
# 55.02099147618845 %
# 34278.67578125 0.6526602506637573
# elastic deform
# gaussian blur
# gaussian noise
# 71.3747842911677 %
# 32690.697265625 0.31894350051879883
# elastic deform
# gaussian blur
# gaussian noise
# 53.0277359437751 %
# 28402.775390625 0.3909569978713989
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 82.26748596571082 %
# 27268.5390625 0.5464237928390503
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 13.412965867004772 %
# 28537.19921875 1.1035029888153076
# gaussian blur
# Random crop along z-axis
# 99.39898005538652 %
# 26120.693359375 1.1955459117889404
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 15.308165308165309 %
# 21699.33984375 1.5345134735107422
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 53.4620106041215 %
# 26254.55859375 1.1396349668502808
# 62.64417981170895 %
# 29275.1328125 0.26264873147010803
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 67.54459864910802 %
# 25250.89453125 0.5044100880622864
# gaussian noise
# 68.26028068355379 %
# 29528.537109375 0.42916348576545715
# gaussian blur
# 99.35615644208288 %
# 22390.2734375 0.9225943088531494
# elastic deform
# gaussian blur
# gaussian noise
# 58.04777701588243 %
# 26082.287109375 0.29235804080963135
# elastic deform
# gaussian blur
# Random crop along z-axis
# 97.93082771758334 %
# 66517.640625 0.7698100209236145
# elastic deform
# Random crop along z-axis
# 81.28369548700806 %
# 114253.7578125 0.22544468939304352
# gaussian noise
# Random crop along z-axis
# 79.85383416626364 %
# 29580.91015625 0.45078733563423157
# gaussian blur
# Random crop along z-axis
# 79.21788258413166 %
# 33634.3046875 0.5538835525512695
# 99.7015176638317 %
# 17437.275390625 1.1758737564086914
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 78.7113582844832 %
# 29118.568359375 0.49598217010498047
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 90.74109622349343 %
# 41734.2578125 0.40020135045051575
# elastic deform
# gaussian blur
# 70.94408315635347 %
# 26037.76953125 0.24749405682086945
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 89.49304369733785 %
# 34921.9375 0.5704401731491089
# elastic deform
# Random crop along z-axis
# 70.82103801423364 %
# 51037.3984375 0.5780907869338989
# gaussian noise
# 99.58582754529323 %
# 19690.638671875 0.8969592452049255
# elastic deform
# gaussian noise
# 49.71917155609047 %
# 31878.951171875 0.25361618399620056
# gaussian blur
# gaussian noise
# 74.3865536971831 %
# 32188.22265625 0.5255556702613831
# Train Epoch: 0 	 Loss: 34403.634883	 acc: 68.000000%	 dice: 73.991717%
# gaussian noise
# 26.08030725650183 %
# 204475.5625 0.0
# elastic deform
# gaussian blur
# gaussian noise
# 12.30814521416815 %
# 141428.484375 1.5497220147153712e-06
# elastic deform
# Random crop along z-axis
# 15.10506446328086 %
# 186545.3125 1.1920930376163597e-07
# elastic deform
# 3.0713714893021034 %
# 95271.53125 3.576279254957626e-07
# Random crop along z-axis
# 98.13538608602055 %
# 66687.6796875 15.249238014221191
# elastic deform
# Random crop along z-axis
# 98.9958108213545 %
# 14961.650390625 14.843772888183594
# elastic deform
# gaussian noise
# 9.8415568936109 %
# 137936.296875 4.768372718899627e-07
# gaussian noise
# Random crop along z-axis
# 24.408258854849525 %
# 149626.109375 1.895445711852517e-05
# gaussian blur
# Random crop along z-axis
# 97.54079078412745 %
# 44705.78125 13.996475219726562
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 16.910579800703786 %
# 205985.046875 2.7299300199956633e-05
# Validation Epoch: 0 	 Loss: 124766.754492	 acc: 70.000000%	 dice: 40.239727%
# --- Saving model at Avg Test Dice:0.40%  ---
# -------------------------------------------------------
# --- 974.4508821964264 seconds ---
# elastic deform
# 40.666991466155366 %
# 26889.263671875 0.48846787214279175
# gaussian noise
# 64.10905280638976 %
# 33455.375 0.4094201326370239
# elastic deform
# gaussian blur
# 68.006032949184 %
# 30713.34765625 0.4009052813053131
# elastic deform
# gaussian blur
# gaussian noise
# 99.4876735143814 %
# 19132.23046875 1.367855429649353
# gaussian blur
# gaussian noise
# 66.93500236766795 %
# 28396.791015625 0.3228554129600525
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 75.77098495875788 %
# 25423.3125 0.1818743646144867
# gaussian noise
# 79.96217225016528 %
# 29021.060546875 0.4314544200897217
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 66.19157452706267 %
# 30777.560546875 0.3830224871635437
# elastic deform
# gaussian blur
# 51.30287381243348 %
# 39125.23828125 0.41806694865226746
# gaussian noise
# Random crop along z-axis
# 99.63525299104272 %
# 20702.255859375 1.570404052734375
# elastic deform
# 68.9126220606119 %
# 24480.068359375 0.34833621978759766
# elastic deform
# Random crop along z-axis
# 66.72977758968248 %
# 29424.923828125 0.41250351071357727
# 68.06223121679736 %
# 27151.15625 0.22047650814056396
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 65.59137155155547 %
# 76370.4921875 1.113431692123413
# elastic deform
# gaussian noise
# 61.16996944246217 %
# 27114.724609375 0.4112931191921234
# 99.11366448945329 %
# 17959.646484375 1.871419906616211
# elastic deform
# gaussian blur
# gaussian noise
# 68.26386780587241 %
# 28910.755859375 0.3505418300628662
# 89.12147968973075 %
# 22762.453125 0.22561414539813995
# gaussian noise
# 16.842828907794104 %
# 30017.658203125 0.4779961109161377
# elastic deform
# gaussian noise
# Random crop along z-axis
# 76.77631479721883 %
# 138075.171875 0.22785010933876038
# elastic deform
# 76.75318836288669 %
# 20710.88671875 0.15152479708194733
# elastic deform
# gaussian blur
# Random crop along z-axis
# 99.02207293573608 %
# 18002.931640625 0.833437442779541
# gaussian blur
# gaussian noise
# 66.49311911056877 %
# 28686.62109375 0.22475050389766693
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 61.80720865817722 %
# 27332.029296875 0.18832352757453918
# elastic deform
# gaussian blur
# 66.58065837300978 %
# 26443.01953125 0.18390412628650665
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 62.7944393224506 %
# 31502.845703125 0.3324126899242401
# gaussian noise
# Random crop along z-axis
# 78.33109538811135 %
# 28322.21875 0.17119672894477844
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 98.4577051555247 %
# 23375.048828125 1.1822891235351562
# gaussian noise
# Random crop along z-axis
# 78.26014258136105 %
# 25912.953125 0.3286588490009308
# gaussian blur
# gaussian noise
# 80.34185623422229 %
# 27256.400390625 0.2483842968940735
# elastic deform
# 69.2063319666567 %
# 27396.732421875 0.23501771688461304
# elastic deform
# gaussian noise
# Random crop along z-axis
# 64.52627188432457 %
# 28892.8046875 0.17414964735507965
# elastic deform
# gaussian blur
# Random crop along z-axis
# 97.03156193321138 %
# 27027.22265625 1.283138632774353
# 99.31213616122334 %
# 19490.966796875 1.4587162733078003
# gaussian blur
# 53.179447632242805 %
# 30166.298828125 0.17334087193012238
# Random crop along z-axis
# 79.47514665020068 %
# 24924.591796875 0.18381120264530182
# gaussian blur
# gaussian noise
# 9.687264247993966 %
# 22293.76953125 0.3838134706020355
# elastic deform
# Random crop along z-axis
# 55.09532110345591 %
# 48710.7109375 0.17971907556056976
# gaussian noise
# 86.53054322553372 %
# 23548.416015625 0.18921302258968353
# 99.11075244116724 %
# 17463.921875 1.2860521078109741
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 76.91808877408756 %
# 35867.296875 0.2143591046333313
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 72.5908067414197 %
# 29664.599609375 0.3093115985393524
# gaussian noise
# Random crop along z-axis
# 68.47082340278313 %
# 27742.603515625 2.089209794998169
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 70.0041158139652 %
# 44767.609375 0.2067699134349823
# gaussian blur
# Random crop along z-axis
# 98.52985398696273 %
# 20181.10546875 0.9048163890838623
# Random crop along z-axis
# 99.77169484437542 %
# 20885.923828125 1.5187736749649048
# gaussian blur
# Random crop along z-axis
# 74.09894041747827 %
# 59958.90234375 0.2504010498523712
# elastic deform
# gaussian blur
# Random crop along z-axis
# 88.1220466754249 %
# 27117.19921875 0.21346984803676605
# gaussian blur
# 49.87094204929276 %
# 29152.056640625 0.3014819324016571
# Random crop along z-axis
# 69.47987315108448 %
# 25348.373046875 0.31558629870414734
# Train Epoch: 1 	 Loss: 31081.538086	 acc: 76.000000%	 dice: 72.850104%
# Random crop along z-axis
# 16.688534993611018 %
# 517651.6875 0.015029756352305412
# elastic deform
# gaussian blur
# Random crop along z-axis
# 99.74646825522977 %
# 10416.8154296875 27.63102149963379
# elastic deform
# gaussian blur
# 11.55886032456434 %
# 249005.6875 0.1973416805267334
# Random crop along z-axis
# 99.0634080837275 %
# 42796.06640625 6.3748250007629395
# gaussian blur
# gaussian noise
# 22.017574032959132 %
# 235761.3125 0.016009243205189705
# gaussian noise
# 10.583679405631779 %
# 91209.8046875 0.0018259257776662707
# elastic deform
# gaussian blur
# gaussian noise
# 21.892933071180806 %
# 272768.6875 0.0807255208492279
# 99.66545615298736 %
# 12103.0126953125 27.63102149963379
# elastic deform
# gaussian blur
# gaussian noise
# 10.592073297702505 %
# 158241.078125 0.02793702855706215
# gaussian noise
# Random crop along z-axis
# 17.23166663337262 %
# 157271.546875 0.04337131232023239
# Validation Epoch: 1 	 Loss: 174728.772656	 acc: 70.000000%	 dice: 40.904065%
# --- Saving model at Avg Test Dice:0.41%  ---
# -------------------------------------------------------
# --- 922.5664982795715 seconds ---
# gaussian blur
# 54.065338574632996 %
# 31394.333984375 0.2358478605747223
# elastic deform
# gaussian blur
# gaussian noise
# 99.00549048615916 %
# 17635.689453125 1.3433055877685547
# 63.85545967648697 %
# 33174.5703125 0.29936695098876953
# gaussian blur
# gaussian noise
# 85.44708851631513 %
# 28295.85546875 0.34379813075065613
# Random crop along z-axis
# 66.01723491944549 %
# 22725.703125 0.19296184182167053
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 81.01952277657267 %
# 29132.7109375 0.27092087268829346
# elastic deform
# gaussian blur
# gaussian noise
# 53.17719943259126 %
# 25240.05859375 0.1156855970621109
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 99.21376091411346 %
# 17585.333984375 0.8018230199813843
# elastic deform
# gaussian noise
# 45.23828167822968 %
# 27435.125 0.193099707365036
# elastic deform
# 64.21705839664696 %
# 26295.6484375 0.20802713930606842
# elastic deform
# Random crop along z-axis
# 97.86613153762181 %
# 71835.6484375 1.1412686109542847
# elastic deform
# gaussian blur
# gaussian noise
# 71.8781292140082 %
# 29025.412109375 0.14337404072284698
# elastic deform
# 55.87790708262762 %
# 23034.8828125 0.14938542246818542
# Random crop along z-axis
# 99.45430224809063 %
# 16249.228515625 1.096261739730835
# gaussian blur
# 80.82533122644949 %
# 24551.01953125 0.16923055052757263
# elastic deform
# gaussian blur
# 90.81299510897017 %
# 19931.591796875 0.4106141924858093
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 85.21675707708438 %
# 30421.90625 0.23205460608005524
# elastic deform
# gaussian noise
# Random crop along z-axis
# 82.93095610889439 %
# 32589.29296875 0.2098686844110489
# 85.92844212110734 %
# 43058.45703125 0.3954295217990875
# gaussian noise
# Random crop along z-axis
# 99.65585457517238 %
# 16456.86328125 1.6325674057006836
# gaussian blur
# Random crop along z-axis
# 98.8970842576525 %
# 18627.767578125 0.7426064014434814
# gaussian noise
# Random crop along z-axis
# 78.63403558794023 %
# 27509.154296875 0.20357368886470795
# Random crop along z-axis
# 83.53410223551188 %
# 23693.865234375 0.2728290557861328
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 9.57354506016207 %
# 22662.8828125 1.144242525100708
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 65.1563345966432 %
# 143884.390625 0.17976795136928558
# elastic deform
# gaussian blur
# Random crop along z-axis
# 99.47666465027413 %
# 16737.962890625 0.6527854800224304
# 86.33944041684128 %
# 56233.265625 0.4683990478515625
# 86.57479685790503 %
# 51256.75390625 0.421062707901001
# elastic deform
# Random crop along z-axis
# 83.9827431382501 %
# 27417.3984375 0.23951135575771332
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 51.85383200887831 %
# 35964.265625 0.16408070921897888
# elastic deform
# gaussian blur
# Random crop along z-axis
# 82.2125441870364 %
# 34460.796875 0.2790623605251312
# elastic deform
# Random crop along z-axis
# 97.8167900620997 %
# 20570.017578125 1.883158564567566
# gaussian blur
# gaussian noise
# 69.36296975252063 %
# 26790.19921875 0.24840232729911804
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 97.13696566722957 %
# 21772.86328125 0.6692978143692017
# gaussian blur
# 66.61662458582596 %
# 33115.5703125 0.2794792354106903
# elastic deform
# Random crop along z-axis
# 77.32338783121557 %
# 31582.490234375 0.12484224885702133
# gaussian noise
# 64.12462094756478 %
# 25625.962890625 0.13384214043617249
# elastic deform
# gaussian noise
# Random crop along z-axis
# 98.68268043876833 %
# 18354.935546875 0.6547486782073975
# gaussian noise
# 47.078760636899965 %
# 29874.884765625 0.25536391139030457
# elastic deform
# gaussian blur
# gaussian noise
# 32.25899280575539 %
# 39559.03125 0.23514936864376068
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 82.86891952390509 %
# 34326.37890625 0.12053029239177704
# gaussian noise
# 44.88393562448249 %
# 31582.255859375 0.32380738854408264
# gaussian noise
# 37.37836650134974 %
# 41672.328125 0.1663484275341034
# Random crop along z-axis
# 98.44887910844868 %
# 26682.5 0.8047176599502563
# elastic deform
# gaussian blur
# gaussian noise
# 46.04803785031574 %
# 27549.908203125 0.19226469099521637
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 54.219423356592976 %
# 44833.5546875 0.23477308452129364
# elastic deform
# gaussian blur
# 21.1464502950004 %
# 27357.12890625 0.1493869423866272
# elastic deform
# gaussian blur
# gaussian noise
# 28.01482837803359 %
# 27275.9296875 0.5244430899620056
# gaussian noise
# 87.82211429950112 %
# 27698.10546875 0.15603792667388916
# elastic deform
# 98.95663544683514 %
# 17709.669921875 0.8229078054428101
# Train Epoch: 2 	 Loss: 31569.477910	 acc: 80.000000%	 dice: 72.762555%
# gaussian noise
# Random crop along z-axis
# 25.23957490142831 %
# 548768.125 0.0
# gaussian blur
# Random crop along z-axis
# 19.71844566579886 %
# 212415.96875 0.0
# Random crop along z-axis
# 19.146871440023627 %
# 222626.578125 0.0
# gaussian noise
# Random crop along z-axis
# 99.04635323561388 %
# 14386.212890625 14.843772888183594
# gaussian noise
# 10.534650478847748 %
# 127654.9296875 0.0
# elastic deform
# 14.945260972915062 %
# 205316.296875 0.0
# elastic deform
# gaussian noise
# 4.332015252083039 %
# 81598.2109375 0.0
# gaussian blur
# gaussian noise
# 9.508144973043919 %
# 168201.109375 0.0
# elastic deform
# Random crop along z-axis
# 98.43975642805049 %
# 54840.46484375 27.63102149963379
# elastic deform
# gaussian noise
# 99.9814714439659 %
# 6065.14599609375 27.63102149963379
# Validation Epoch: 2 	 Loss: 164194.314990	 acc: 70.000000%	 dice: 40.089254%
# -------------------------------------------------------
# --- 928.2428238391876 seconds ---
# gaussian blur
# 84.42875283795745 %
# 22913.306640625 0.17019633948802948
# elastic deform
# gaussian noise
# Random crop along z-axis
# 35.849480483010396 %
# 66965.3515625 0.6250936985015869
# 66.48660641078818 %
# 33033.94140625 0.1396740972995758
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 69.72322844899023 %
# 31499.79296875 0.18883728981018066
# gaussian noise
# Random crop along z-axis
# 87.35526973355428 %
# 54934.8203125 0.29355373978614807
# 99.2010931827243 %
# 15901.4560546875 1.3179007768630981
# gaussian noise
# Random crop along z-axis
# 81.20885367955842 %
# 24080.501953125 0.409877210855484
# Random crop along z-axis
# 70.07246083471644 %
# 20761.533203125 0.12097053974866867
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 86.53273363318341 %
# 60225.0390625 0.17194601893424988
# gaussian noise
# 68.67274215845491 %
# 21984.490234375 0.22413413226604462
# gaussian blur
# Random crop along z-axis
# 60.59594386460046 %
# 37765.640625 0.1475146859884262
# Random crop along z-axis
# 98.80851683917511 %
# 17343.552734375 1.570106029510498
# elastic deform
# Random crop along z-axis
# 51.066181186663115 %
# 32740.12109375 0.15882687270641327
# elastic deform
# gaussian blur
# gaussian noise
# 25.78397212543554 %
# 30775.92578125 0.22067084908485413
# elastic deform
# gaussian blur
# gaussian noise
# 61.13739844656727 %
# 25071.26171875 0.14060625433921814
# elastic deform
# gaussian blur
# gaussian noise
# 83.18320292809082 %
# 41211.65234375 0.27139678597450256
# elastic deform
# gaussian blur
# gaussian noise
# 79.6573836060097 %
# 23826.8515625 0.12785783410072327
# Random crop along z-axis
# 98.82409018235431 %
# 16985.703125 0.9849349856376648
# elastic deform
# gaussian noise
# 46.579362606659366 %
# 32870.51953125 0.11387692391872406
# elastic deform
# gaussian blur
# 83.1179076400267 %
# 24413.884765625 0.08383508026599884
# elastic deform
# gaussian noise
# Random crop along z-axis
# 60.09989268822618 %
# 25560.234375 0.2936469316482544
# elastic deform
# gaussian blur
# Random crop along z-axis
# 56.02558462215303 %
# 49875.078125 0.9026834964752197
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 36.93707647628267 %
# 23556.724609375 0.39877375960350037
# gaussian blur
# 98.18167694324417 %
# 19224.154296875 2.0095903873443604
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 6.553836097255972 %
# 20496.64453125 1.377253532409668
# elastic deform
# gaussian blur
# Random crop along z-axis
# 73.16212241203756 %
# 27829.1484375 0.09666242450475693
# Random crop along z-axis
# 83.87360512650535 %
# 32849.63671875 2.3513526916503906
# elastic deform
# gaussian blur
# Random crop along z-axis
# 63.80136625147933 %
# 24359.76171875 0.2285928875207901
# Random crop along z-axis
# 73.30875112610254 %
# 30902.970703125 0.22415681183338165
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 99.27930125937374 %
# 17552.373046875 2.0570147037506104
# gaussian blur
# 59.48245092207019 %
# 32920.35546875 0.6635217666625977
# gaussian noise
# Random crop along z-axis
# 81.0753292643752 %
# 23869.5625 0.18673735857009888
# gaussian blur
# Random crop along z-axis
# 68.9096427737567 %
# 22025.068359375 0.1587948054075241
# elastic deform
# Random crop along z-axis
# 98.889480036941 %
# 16504.376953125 1.0229451656341553
# gaussian blur
# gaussian noise
# 76.74990450725745 %
# 22982.0390625 0.2350337654352188
# gaussian blur
# gaussian noise
# 99.22664337082388 %
# 15979.3154296875 2.2477684020996094
# elastic deform
# gaussian noise
# Random crop along z-axis
# 77.08105691864507 %
# 25406.142578125 0.12766730785369873
# elastic deform
# gaussian blur
# Random crop along z-axis
# 79.33930259718592 %
# 24601.984375 0.10785459727048874
# elastic deform
# 39.26783354027316 %
# 20221.986328125 0.6044124364852905
# elastic deform
# gaussian noise
# Random crop along z-axis
# 87.55931174412474 %
# 60606.4765625 0.23726952075958252
# elastic deform
# gaussian blur
# Random crop along z-axis
# 83.78766396475929 %
# 24452.357421875 0.2256406545639038
# Random crop along z-axis
# 99.24012767757641 %
# 16617.888671875 1.5285959243774414
# elastic deform
# 87.15172322725472 %
# 41300.15625 0.15435673296451569
# gaussian noise
# 69.31998468187538 %
# 26893.439453125 0.15438872575759888
# gaussian blur
# Random crop along z-axis
# 69.37757887782196 %
# 38548.88671875 0.12171616405248642
# elastic deform
# gaussian noise
# 19.596937386838338 %
# 22451.9296875 0.5071984529495239
# gaussian blur
# Random crop along z-axis
# 57.10590973748868 %
# 26626.76953125 0.14713157713413239
# Random crop along z-axis
# 99.68750881915834 %
# 17657.279296875 1.9441639184951782
# gaussian blur
# Random crop along z-axis
# 72.47769871877527 %
# 26050.029296875 0.26089581847190857
# elastic deform
# gaussian blur
# gaussian noise
# 49.10456018335573 %
# 26281.12109375 0.15882107615470886
# Train Epoch: 3 	 Loss: 28790.749062	 acc: 76.000000%	 dice: 71.278781%
# elastic deform
# 12.072082752897241 %
# 293614.46875 0.0
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 19.64408934083893 %
# 483172.09375 0.0
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 7.037689847699663 %
# 150918.671875 0.0
# elastic deform
# 5.172472065811799 %
# 188681.59375 0.0
# 4.718232167333429 %
# 367255.1875 0.0
# 98.1093537287719 %
# 13912.541015625 27.63102149963379
# 18.038294679844732 %
# 202971.828125 0.0
# gaussian blur
# gaussian noise
# 14.056746385518817 %
# 104749.3984375 0.0
# elastic deform
# gaussian noise
# Random crop along z-axis
# 11.151487622075857 %
# 284167.75 0.0
# gaussian blur
# 5.755304146830236 %
# 101388.46875 0.0
# Validation Epoch: 3 	 Loss: 219085.963281	 acc: 90.000000%	 dice: 19.575575%
# -------------------------------------------------------
# --- 930.8188529014587 seconds ---
# 80.98097407228472 %
# 23021.82421875 0.18980015814304352
# elastic deform
# gaussian noise
# 79.86518223704262 %
# 31869.2109375 0.1958518624305725
# elastic deform
# gaussian blur
# gaussian noise
# 81.48194388089516 %
# 21394.615234375 0.23897536098957062
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 98.73405007882913 %
# 17300.166015625 1.2654138803482056
# gaussian blur
# gaussian noise
# 6.909736783679107 %
# 22848.56640625 1.0934605598449707
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 78.24508244957241 %
# 24541.638671875 0.22771252691745758
# gaussian blur
# 64.19695386814757 %
# 30543.30078125 0.0852392241358757
# Random crop along z-axis
# 84.43442618593203 %
# 52997.15625 0.519373893737793
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 0.6832216528708448 %
# 77438.5546875 0.6579059362411499
# elastic deform
# gaussian noise
# 99.55146297216551 %
# 17492.404296875 1.4682904481887817
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 51.757565171826556 %
# 45594.953125 0.881087601184845
# Random crop along z-axis
# 85.25253278405862 %
# 32685.203125 0.08011218160390854
# elastic deform
# gaussian blur
# gaussian noise
# 74.54228635939724 %
# 23543.595703125 0.40442484617233276
# elastic deform
# gaussian noise
# 63.02150619347975 %
# 21577.13671875 0.15327778458595276
# elastic deform
# gaussian noise
# 87.47135805127101 %
# 23538.30859375 0.15263983607292175
# gaussian noise
# Random crop along z-axis
# 99.26432743397477 %
# 16044.578125 1.2958415746688843
# 88.5639610626057 %
# 38400.5703125 1.7752505540847778
# elastic deform
# gaussian noise
# Random crop along z-axis
# 10.044600791507003 %
# 18314.09765625 1.0436832904815674
# elastic deform
# Random crop along z-axis
# 91.0141592289559 %
# 37194.7109375 0.22211581468582153
# elastic deform
# gaussian blur
# 82.10011195364888 %
# 21825.623046875 0.20303025841712952
# elastic deform
# gaussian noise
# 61.76131132234512 %
# 34941.27734375 0.14697815477848053
# Random crop along z-axis
# 98.36930170910865 %
# 18095.4375 1.470923662185669
# 76.78374480359719 %
# 20881.458984375 0.22342818975448608
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 74.36924605481508 %
# 29467.619140625 0.24517259001731873
# gaussian blur
# Random crop along z-axis
# 73.0384012465621 %
# 28534.1953125 0.46470174193382263
# elastic deform
# 85.78929667921498 %
# 21135.732421875 0.31669360399246216
# elastic deform
# 58.201392377808084 %
# 25361.060546875 0.16925068199634552
# elastic deform
# gaussian blur
# Random crop along z-axis
# 99.37407244445703 %
# 18250.294921875 1.5185633897781372
# elastic deform
# gaussian noise
# 59.10384911926933 %
# 27933.427734375 0.3343254327774048
# gaussian blur
# gaussian noise
# 69.9826204248917 %
# 28307.96875 0.2718880772590637
# elastic deform
# gaussian blur
# 83.52853071498409 %
# 22142.150390625 0.381050169467926
# Random crop along z-axis
# 81.03132161955692 %
# 19332.42578125 0.9453285932540894
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 57.79857199875826 %
# 18617.052734375 0.15872201323509216
# elastic deform
# gaussian noise
# Random crop along z-axis
# 99.17291241275628 %
# 19816.73828125 1.1314746141433716
# 77.01765007218367 %
# 20277.818359375 0.2910698652267456
# gaussian noise
# Random crop along z-axis
# 81.69031509762227 %
# 56971.19140625 0.26717785000801086
# gaussian blur
# gaussian noise
# 79.46887318615067 %
# 20768.064453125 0.23731781542301178
# elastic deform
# 79.3008659728291 %
# 19321.72265625 0.20746280252933502
# elastic deform
# 62.832644156371295 %
# 20345.650390625 0.19324244558811188
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 99.63539708743603 %
# 15731.8271484375 0.9314396381378174
# elastic deform
# 76.01344492318798 %
# 18392.916015625 0.5195815563201904
# gaussian blur
# 85.59642075385466 %
# 19599.54296875 0.2603009045124054
# elastic deform
# Random crop along z-axis
# 92.30672900317248 %
# 33589.1953125 0.1944136917591095
# elastic deform
# gaussian noise
# Random crop along z-axis
# 87.22365356704881 %
# 41301.859375 0.41327965259552
# gaussian noise
# 89.05927122031639 %
# 19059.791015625 0.1946965903043747
# gaussian noise
# 99.5874622223414 %
# 16044.1943359375 1.5238819122314453
# elastic deform
# gaussian blur
# 87.00055035773254 %
# 19998.626953125 0.5354161262512207
# gaussian blur
# Random crop along z-axis
# 88.64672034012192 %
# 24981.05859375 0.9971141815185547
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 69.31129007058956 %
# 25346.26953125 0.17252671718597412
# 79.53849567339694 %
# 21056.806640625 0.27023735642433167
# Train Epoch: 4 	 Loss: 26475.934590	 acc: 72.000000%	 dice: 76.412996%
# elastic deform
# gaussian blur
# gaussian noise
# 13.030913389964095 %
# 114452.2109375 0.000851636053994298
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 99.78527313462756 %
# 9499.1552734375 27.63102149963379
# gaussian blur
# Random crop along z-axis
# 11.282610907140413 %
# 543323.5625 7.164735143305734e-05
# elastic deform
# Random crop along z-axis
# 98.65002140905405 %
# 24562.583984375 11.180211067199707
# 17.439331784708152 %
# 352762.09375 7.605842256452888e-05
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 16.22805442860733 %
# 254443.21875 0.00019057421013712883
# gaussian noise
# Random crop along z-axis
# 8.993551523470453 %
# 218190.546875 2.837221290974412e-05
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 99.99952316056805 %
# 7843.79833984375 27.63102149963379
# elastic deform
# gaussian noise
# Random crop along z-axis
# 14.226592228425408 %
# 155130.734375 2.1338690203265287e-05
# gaussian noise
# Random crop along z-axis
# 15.551746939987316 %
# 270158.15625 5.245222382654902e-06
# Validation Epoch: 4 	 Loss: 195043.250244	 acc: 70.000000%	 dice: 39.518762%
# -------------------------------------------------------
# --- 926.6925721168518 seconds ---
# gaussian blur
# Random crop along z-axis
# 56.00862381889981 %
# 24609.759765625 0.18302392959594727
# elastic deform
# gaussian noise
# 99.18100721305927 %
# 14476.578125 1.109402060508728
# 61.861299872681805 %
# 31405.158203125 0.5552325248718262
# gaussian noise
# Random crop along z-axis
# 91.97482996016126 %
# 23778.42578125 0.23877358436584473
# gaussian blur
# gaussian noise
# 23.177595911461033 %
# 17096.96484375 0.39682894945144653
# elastic deform
# gaussian noise
# 84.13048770591577 %
# 24354.525390625 0.20905980467796326
# gaussian noise
# 76.37005105199826 %
# 26307.12109375 0.16301029920578003
# elastic deform
# gaussian noise
# 99.290159940318 %
# 14795.75 1.7348328828811646
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 57.35783998597393 %
# 22188.66796875 0.12250357121229172
# elastic deform
# Random crop along z-axis
# 98.82216208170978 %
# 15414.8173828125 1.2026379108428955
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 89.96503596709941 %
# 26857.466796875 0.15143074095249176
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 78.47008204922955 %
# 176421.75 0.11054758727550507
# elastic deform
# 77.21143096702068 %
# 18887.23828125 0.11921104788780212
# elastic deform
# gaussian blur
# gaussian noise
# 99.74006975137625 %
# 17799.712890625 1.5419692993164062
# gaussian noise
# Random crop along z-axis
# 82.43071599307909 %
# 24120.482421875 0.44056063890457153
# gaussian blur
# gaussian noise
# 80.8766859344894 %
# 22495.5390625 0.1572970300912857
# elastic deform
# 56.99591719790846 %
# 30007.90234375 0.3200334310531616
# elastic deform
# gaussian blur
# gaussian noise
# 59.604232677706705 %
# 20208.5234375 0.08833330869674683
# elastic deform
# 35.95934708962119 %
# 25056.564453125 0.16305366158485413
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 98.29872451014647 %
# 18743.94921875 1.9319407939910889
# gaussian blur
# gaussian noise
# 34.82460512520839 %
# 18754.072265625 0.22574321925640106
# 39.23443834963034 %
# 29820.35546875 0.1589248925447464
# elastic deform
# 79.96981166080923 %
# 19214.181640625 0.3035458028316498
# gaussian blur
# 84.09407191448007 %
# 24551.837890625 0.2800019085407257
# 54.944001394517805 %
# 23745.85546875 0.17555467784404755
# gaussian blur
# gaussian noise
# 98.5122499950397 %
# 16345.6279296875 2.0944509506225586
# gaussian blur
# Random crop along z-axis
# 92.38535031847134 %
# 55487.6484375 0.10630843788385391
# elastic deform
# gaussian blur
# Random crop along z-axis
# 76.68060280535207 %
# 26281.044921875 0.46182507276535034
# 57.51501236312257 %
# 22202.21484375 0.40252798795700073
# 73.71426685152174 %
# 19256.234375 0.2504216432571411
# 63.51539705253768 %
# 32185.22265625 0.08591202646493912
# elastic deform
# gaussian blur
# 98.02463180661776 %
# 16781.1953125 1.327816367149353
# gaussian noise
# Random crop along z-axis
# 41.083461436216325 %
# 45500.796875 0.24459458887577057
# gaussian blur
# 75.8697976942121 %
# 28687.001953125 0.12647855281829834
# 56.521507722768064 %
# 25847.162109375 0.19532710313796997
# elastic deform
# gaussian noise
# 65.85395390142493 %
# 18725.046875 0.14172972738742828
# elastic deform
# gaussian noise
# 78.98786352186856 %
# 25471.29296875 0.13691885769367218
# elastic deform
# gaussian blur
# Random crop along z-axis
# 98.73292539711971 %
# 14866.46875 0.8433908224105835
# gaussian blur
# Random crop along z-axis
# 98.8232115633262 %
# 14777.1630859375 1.1544959545135498
# gaussian noise
# Random crop along z-axis
# 88.11776355133773 %
# 28276.845703125 0.11898108571767807
# gaussian noise
# 64.56892513707878 %
# 34123.1875 1.614156723022461
# elastic deform
# gaussian blur
# 68.15537006892252 %
# 24390.62109375 0.3719455301761627
# gaussian noise
# 73.40635367904376 %
# 30314.12109375 0.14654403924942017
# Random crop along z-axis
# 99.5450395515732 %
# 14389.041015625 1.0790913105010986
# Random crop along z-axis
# 87.04552863196784 %
# 22438.1015625 0.15495659410953522
# elastic deform
# Random crop along z-axis
# 99.27088356615748 %
# 16354.5517578125 0.9108184576034546
# elastic deform
# gaussian blur
# gaussian noise
# 69.42112669222185 %
# 18960.115234375 0.10834057629108429
# elastic deform
# Random crop along z-axis
# 89.51674303354143 %
# 28964.2578125 0.22670148313045502
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 78.66505814012429 %
# 29936.677734375 0.6912910342216492
# elastic deform
# gaussian blur
# gaussian noise
# 99.78857734702679 %
# 14989.8720703125 1.090800166130066
# Train Epoch: 5 	 Loss: 26733.817559	 acc: 74.000000%	 dice: 75.890297%
# elastic deform
# gaussian blur
# Random crop along z-axis
# 3.174693160236968 %
# 201662.5625 0.00013447711535263807
# elastic deform
# 5.42923573995229 %
# 153447.921875 0.0
# elastic deform
# gaussian blur
# gaussian noise
# 5.05974808913769 %
# 219620.96875 0.0
# gaussian blur
# 99.96403354706501 %
# 5575.14990234375 27.63102149963379
# elastic deform
# gaussian blur
# Random crop along z-axis
# 0.27242654212881884 %
# 42314.66796875 7.510641098022461
# elastic deform
# gaussian blur
# gaussian noise
# 4.654197477163984 %
# 140840.46875 1.1920930376163597e-07
# elastic deform
# gaussian blur
# 3.755978070687041 %
# 99251.9609375 7.152560215217818e-07
# elastic deform
# gaussian blur
# Random crop along z-axis
# 4.041141482897082 %
# 292290.03125 1.1920930376163597e-07
# gaussian blur
# 3.2135764578443764 %
# 127610.78125 0.0004034260055050254
# elastic deform
# gaussian noise
# Random crop along z-axis
# 99.89919046891707 %
# 7430.15966796875 27.63102149963379
# Validation Epoch: 5 	 Loss: 129010.744629	 acc: 70.000000%	 dice: 22.946422%
# -------------------------------------------------------
# --- 926.6865656375885 seconds ---
# Random crop along z-axis
# 89.02564542413586 %
# 22361.60546875 0.41646599769592285
# elastic deform
# gaussian noise
# Random crop along z-axis
# 83.00092542362064 %
# 20237.841796875 0.32938218116760254
# gaussian noise
# Random crop along z-axis
# 0.0 %
# 59866.6796875 1.0558853149414062
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 80.45353831680839 %
# 23947.080078125 0.2923864722251892
# gaussian blur
# 81.86076608195361 %
# 24003.16015625 0.26804986596107483
# elastic deform
# 99.67325608207732 %
# 13813.65625 1.059556007385254
# 79.92761322884844 %
# 39135.8125 0.5136512517929077
# gaussian noise
# 79.06307136378688 %
# 24580.556640625 0.6936789155006409
# elastic deform
# 89.39953333136427 %
# 20656.998046875 0.4889298677444458
# gaussian noise
# 81.13844788482399 %
# 24075.705078125 0.21942457556724548
# gaussian blur
# 76.82511366311121 %
# 20806.80859375 0.10480313003063202
# elastic deform
# gaussian noise
# Random crop along z-axis
# 99.6803109732792 %
# 15348.3583984375 0.9087615013122559
# elastic deform
# gaussian blur
# gaussian noise
# 82.68466873855147 %
# 21479.80078125 0.10467618703842163
# elastic deform
# gaussian noise
# Random crop along z-axis
# 99.50811903088189 %
# 15951.2734375 0.6584893465042114
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 98.79301196371001 %
# 48466.32421875 0.8039768934249878
# gaussian blur
# Random crop along z-axis
# 48.72743306469392 %
# 17760.998046875 0.9651962518692017
# elastic deform
# Random crop along z-axis
# 82.56857726605546 %
# 37730.0703125 0.2733217775821686
# elastic deform
# gaussian noise
# 99.80353934946298 %
# 13874.8095703125 0.4819321930408478
# elastic deform
# Random crop along z-axis
# 84.92581527878895 %
# 86932.9921875 0.30933284759521484
# elastic deform
# Random crop along z-axis
# 86.00481962903461 %
# 19970.79296875 0.18554377555847168
# gaussian blur
# Random crop along z-axis
# 84.13064042112256 %
# 22874.814453125 0.12132107466459274
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 76.8395061728395 %
# 21482.31640625 0.2559936046600342
# gaussian blur
# 68.70130549213044 %
# 23772.3359375 0.22113598883152008
# elastic deform
# gaussian noise
# 99.45999018163967 %
# 13634.244140625 1.4994717836380005
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 73.1820207769054 %
# 32900.62890625 0.13899922370910645
# gaussian blur
# gaussian noise
# 44.18822807047466 %
# 27695.6875 0.15448805689811707
# gaussian blur
# 66.72624053826746 %
# 29858.658203125 0.1014847531914711
# Random crop along z-axis
# 98.52828288864251 %
# 16895.271484375 0.8922477960586548
# elastic deform
# gaussian noise
# 41.43094568132826 %
# 21054.8359375 0.5290955901145935
# elastic deform
# gaussian blur
# 99.74670788370219 %
# 15772.939453125 1.0227636098861694
# 46.77401652581571 %
# 31422.46875 0.4751652479171753
# 88.55817549284886 %
# 23039.80859375 0.20956462621688843
# 89.28768222913081 %
# 32158.44921875 0.36779046058654785
# gaussian blur
# Random crop along z-axis
# 98.8469777117729 %
# 15900.4404296875 0.6263399124145508
# gaussian blur
# gaussian noise
# 49.94965490727349 %
# 25564.583984375 0.19964876770973206
# elastic deform
# gaussian blur
# gaussian noise
# 98.99393790817014 %
# 16923.90625 1.2973605394363403
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 56.542932991578176 %
# 33329.64453125 0.17030489444732666
# Random crop along z-axis
# 79.78006925155054 %
# 29424.140625 0.19495217502117157
# elastic deform
# gaussian noise
# 70.66929943642273 %
# 21146.75390625 0.11662096530199051
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 67.82807226523725 %
# 30598.13671875 0.3653075397014618
# Random crop along z-axis
# 49.6675791943684 %
# 21518.00390625 0.48438823223114014
# elastic deform
# Random crop along z-axis
# 99.1096361114178 %
# 14030.3125 0.7982388734817505
# elastic deform
# gaussian blur
# gaussian noise
# 66.65586869668503 %
# 30756.01171875 0.511466920375824
# elastic deform
# 76.51733991224646 %
# 17581.412109375 0.20847190916538239
# elastic deform
# gaussian blur
# Random crop along z-axis
# 77.873356764209 %
# 27730.23828125 1.5106351375579834
# elastic deform
# Random crop along z-axis
# 83.50155811011375 %
# 37207.17578125 0.7670231461524963
# Random crop along z-axis
# 89.844466590313 %
# 28027.3984375 0.17492586374282837
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 99.15562784535913 %
# 14810.0908203125 0.8885388970375061
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 63.352071040350076 %
# 21850.9375 0.8808354735374451
# elastic deform
# gaussian noise
# 87.22602710733727 %
# 21810.974609375 0.2808724641799927
# Train Epoch: 6 	 Loss: 25835.990879	 acc: 70.000000%	 dice: 78.322648%
# 9.529007258636685 %
# 133103.171875 0.0002974117815028876
# gaussian blur
# 2.2661561303430493 %
# 154442.59375 0.04625799506902695
# elastic deform
# gaussian noise
# Random crop along z-axis
# 1.4964086193136472 %
# 188369.4375 3.212433338165283
# elastic deform
# Random crop along z-axis
# 7.723450638430396 %
# 532017.4375 0.0024572378024458885
# elastic deform
# gaussian noise
# Random crop along z-axis
# 7.676829914027977 %
# 576104.6875 0.0004618041857611388
# elastic deform
# gaussian blur
# gaussian noise
# 99.79319809023596 %
# 6053.90478515625 15.942384719848633
# elastic deform
# gaussian noise
# 8.14037452462331 %
# 133094.40625 4.744642137666233e-05
# gaussian blur
# Random crop along z-axis
# 2.240566037735849 %
# 108848.2890625 5.978555202484131
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 3.0625715040042243 %
# 323112.25 0.002386315492913127
# elastic deform
# 3.7188728702490166 %
# 73208.4140625 0.004909986164420843
# Validation Epoch: 6 	 Loss: 222837.978467	 acc: 70.000000%	 dice: 14.564744%
# -------------------------------------------------------
# --- 933.4054114818573 seconds ---
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 35.03140799754864 %
# 30737.978515625 1.0638498067855835
# elastic deform
# Random crop along z-axis
# 89.13751074412771 %
# 63286.53125 0.10524240136146545
# 73.2824427480916 %
# 21926.474609375 0.19049882888793945
# elastic deform
# Random crop along z-axis
# 99.63575732660905 %
# 14101.1396484375 1.0446178913116455
# gaussian noise
# Random crop along z-axis
# 76.3900213894896 %
# 22860.076171875 0.45171982049942017
# elastic deform
# Random crop along z-axis
# 88.89502100829398 %
# 27795.505859375 0.30401843786239624
# elastic deform
# Random crop along z-axis
# 57.900860529680784 %
# 30382.4921875 0.5406164526939392
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 78.30692372401244 %
# 22992.0390625 0.7710815668106079
# elastic deform
# Random crop along z-axis
# 83.4893846969209 %
# 49342.4140625 0.6234192848205566
# gaussian blur
# Random crop along z-axis
# 99.58686124431925 %
# 14214.7060546875 0.7436003088951111
# elastic deform
# Random crop along z-axis
# 89.85552383424171 %
# 24101.025390625 0.2740618884563446
# gaussian blur
# gaussian noise
# 64.55309127974412 %
# 20800.84375 0.08625977486371994
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 87.24837762989294 %
# 32086.1171875 0.1377090960741043
# elastic deform
# 72.18980130609977 %
# 19404.619140625 0.16314662992954254
# elastic deform
# gaussian blur
# gaussian noise
# 65.17933262088592 %
# 37506.86328125 0.6761028170585632
# Random crop along z-axis
# 99.08210834292753 %
# 17392.154296875 1.6210095882415771
# elastic deform
# gaussian noise
# 80.0593485253477 %
# 20641.171875 0.25480738282203674
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 98.30402613159485 %
# 16954.37890625 0.7851684093475342
# elastic deform
# 73.04519960409107 %
# 18081.4765625 0.2177790105342865
# elastic deform
# gaussian noise
# Random crop along z-axis
# 81.80491992353105 %
# 27927.15625 0.41215088963508606
# elastic deform
# gaussian blur
# gaussian noise
# 81.25283018867925 %
# 20097.087890625 0.2699984908103943
# 99.67148020485244 %
# 13383.3310546875 1.0433663129806519
# elastic deform
# gaussian blur
# Random crop along z-axis
# 85.06170699893278 %
# 111984.171875 0.5003929734230042
# gaussian blur
# Random crop along z-axis
# 70.83724584634842 %
# 29040.43359375 0.2732766568660736
# elastic deform
# Random crop along z-axis
# 66.62325484475933 %
# 23833.93359375 0.34623202681541443
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 97.42650655209788 %
# 22850.328125 0.8124781847000122
# gaussian blur
# 60.382784609282034 %
# 19026.828125 0.16568231582641602
# elastic deform
# gaussian noise
# 99.56801092268375 %
# 14192.837890625 1.1805577278137207
# gaussian blur
# Random crop along z-axis
# 62.870528648306426 %
# 21347.03515625 0.15581730008125305
# gaussian noise
# Random crop along z-axis
# 55.40785498489426 %
# 20139.71484375 2.5300662517547607
# elastic deform
# 65.86322663157766 %
# 50782.1953125 0.46115589141845703
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 82.966991947955 %
# 19589.853515625 0.3918125629425049
# gaussian blur
# 76.05066849831478 %
# 18864.421875 0.12441089004278183
# elastic deform
# gaussian blur
# 99.46452078685243 %
# 15050.1787109375 1.028710126876831
# gaussian blur
# 83.61602169052053 %
# 29788.99609375 0.13881923258304596
# elastic deform
# gaussian blur
# Random crop along z-axis
# 98.62790218229075 %
# 15657.791015625 0.5144802331924438
# 69.5066601449193 %
# 26740.0078125 0.10686802119016647
# Random crop along z-axis
# 81.010050737561 %
# 21458.236328125 0.3110884130001068
# gaussian noise
# 74.15001377115402 %
# 49981.546875 0.8248332738876343
# gaussian noise
# Random crop along z-axis
# 99.48061559226886 %
# 16718.849609375 1.2994762659072876
# gaussian noise
# 75.7566949334614 %
# 21525.900390625 0.15248924493789673
# gaussian blur
# 67.66886661777886 %
# 21018.462890625 0.257198691368103
# gaussian blur
# gaussian noise
# 73.35496128940532 %
# 30203.603515625 0.5873311758041382
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 62.269932342114465 %
# 22210.923828125 0.5624464154243469
# elastic deform
# gaussian blur
# gaussian noise
# 83.86456679756037 %
# 20551.560546875 0.29729339480400085
# elastic deform
# gaussian noise
# Random crop along z-axis
# 99.46589434712817 %
# 14894.375 0.6495165824890137
# elastic deform
# gaussian noise
# 76.65608780104657 %
# 19082.83203125 0.5699014067649841
# gaussian blur
# gaussian noise
# 78.21227601587013 %
# 27662.05859375 1.0571699142456055
# elastic deform
# gaussian blur
# Random crop along z-axis
# 97.68453016355629 %
# 68861.2421875 0.6597635746002197
# gaussian blur
# 86.7487461630072 %
# 21744.4609375 0.28065890073776245
# Train Epoch: 7 	 Loss: 27216.927676	 acc: 72.000000%	 dice: 80.089987%
# elastic deform
# gaussian blur
# gaussian noise
# 13.20581248264585 %
# 161864.03125 8.344653679159819e-07
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 99.74881656486515 %
# 12712.87109375 9.661989212036133
# gaussian noise
# Random crop along z-axis
# 17.99247946055455 %
# 219685.3125 0.00073286920087412
# elastic deform
# gaussian blur
# Random crop along z-axis
# 38.424655937458716 %
# 288872.40625 0.009716114029288292
# gaussian blur
# gaussian noise
# 29.089089696161075 %
# 170408.109375 0.013562564738094807
# gaussian blur
# 8.670565814549517 %
# 134394.171875 0.00021477859991136938
# elastic deform
# gaussian blur
# Random crop along z-axis
# 26.51822436533825 %
# 162364.859375 0.01609664410352707
# elastic deform
# gaussian blur
# Random crop along z-axis
# 100.0 %
# 7336.97802734375 27.63102149963379
# elastic deform
# gaussian blur
# Random crop along z-axis
# 98.11358612968273 %
# 67212.9765625 7.051492691040039
# Random crop along z-axis
# 44.5613441881031 %
# 278658.34375 0.0018507072236388922
# Validation Epoch: 7 	 Loss: 150355.443896	 acc: 70.000000%	 dice: 47.632457%
# --- Saving model at Avg Test Dice:0.48%  ---
# -------------------------------------------------------
# --- 934.8616032600403 seconds ---
# elastic deform
# gaussian blur
# gaussian noise
# 70.54416843043333 %
# 24265.326171875 0.6473629474639893
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 99.56858807835765 %
# 13428.712890625 0.9076094627380371
# elastic deform
# 58.26812410559328 %
# 21871.6875 0.6366754770278931
# gaussian noise
# 81.52332805457425 %
# 19682.474609375 0.2822282910346985
# elastic deform
# gaussian blur
# 70.08937262189187 %
# 22677.095703125 0.21847347915172577
# gaussian noise
# 60.783945986496626 %
# 18380.263671875 0.15179379284381866
# elastic deform
# Random crop along z-axis
# 38.395219803670514 %
# 16254.0947265625 0.9729111790657043
# 99.27927707261573 %
# 13147.7568359375 1.235446810722351
# gaussian blur
# 88.41797588600657 %
# 30008.099609375 0.20321612060070038
# 80.58569652044574 %
# 18896.173828125 0.17744180560112
# elastic deform
# gaussian blur
# gaussian noise
# 82.26959144049242 %
# 16599.84375 0.5080311298370361
# elastic deform
# gaussian blur
# Random crop along z-axis
# 30.105232809571863 %
# 16899.55078125 0.7643253207206726
# elastic deform
# gaussian blur
# Random crop along z-axis
# 88.0427507287056 %
# 25409.8203125 0.09597126394510269
# elastic deform
# gaussian blur
# Random crop along z-axis
# 99.64521868291624 %
# 13699.1748046875 1.2297803163528442
# elastic deform
# gaussian noise
# 82.63174066676909 %
# 17195.16796875 0.5867840647697449
# elastic deform
# gaussian noise
# 0.346149353889933 %
# 59024.09765625 0.7493138313293457
# elastic deform
# gaussian blur
# gaussian noise
# 86.52756598604034 %
# 18924.6171875 0.1352090835571289
# elastic deform
# gaussian noise
# 83.69451848418124 %
# 17821.8359375 0.0723005160689354
# elastic deform
# gaussian blur
# 79.32566173987583 %
# 23553.953125 0.42115452885627747
# gaussian noise
# 99.58784684450028 %
# 13000.41796875 1.0960493087768555
# gaussian blur
# 62.1201807042515 %
# 17407.162109375 0.3538985252380371
# 89.44375015940219 %
# 18212.814453125 0.16165703535079956
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 89.31871451267035 %
# 25509.619140625 0.2937493622303009
# elastic deform
# Random crop along z-axis
# 78.35989147464556 %
# 25997.390625 0.3172929883003235
# Random crop along z-axis
# 92.82840703799852 %
# 41302.27734375 0.1397380530834198
# elastic deform
# Random crop along z-axis
# 99.57301271815368 %
# 13128.953125 0.9259247779846191
# gaussian noise
# Random crop along z-axis
# 80.38064032626315 %
# 18617.890625 0.2360864132642746
# elastic deform
# gaussian blur
# gaussian noise
# 82.8606942860438 %
# 18853.3515625 0.5205034613609314
# gaussian noise
# Random crop along z-axis
# 90.49770192998514 %
# 17324.544921875 0.10931085050106049
# elastic deform
# gaussian blur
# gaussian noise
# 45.25869628763519 %
# 26974.96875 0.4244481921195984
# elastic deform
# gaussian blur
# gaussian noise
# 63.35882143992223 %
# 19721.955078125 0.11166008561849594
# gaussian blur
# 99.43672825261083 %
# 12688.2705078125 1.1908642053604126
# gaussian noise
# Random crop along z-axis
# 92.12600302846037 %
# 25335.677734375 0.26686444878578186
# elastic deform
# Random crop along z-axis
# 73.62119475226085 %
# 34612.19140625 0.07564658671617508
# 81.8599813892386 %
# 18067.994140625 0.20139209926128387
# gaussian blur
# gaussian noise
# 43.609175969918674 %
# 25161.6875 0.2625165283679962
# elastic deform
# gaussian blur
# 83.24016951880265 %
# 20028.46875 0.27514374256134033
# gaussian blur
# 98.42423672944905 %
# 15329.53125 1.4290180206298828
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 83.59721342621913 %
# 34846.1640625 0.1772240251302719
# elastic deform
# gaussian noise
# 26.07746863066012 %
# 19669.166015625 0.40383777022361755
# gaussian noise
# 74.29949380206466 %
# 17328.470703125 0.272876501083374
# elastic deform
# gaussian blur
# gaussian noise
# ...
# 74.6291163100122 %
# 26062.23828125 0.0
# gaussian blur
# 6.452650023309274 %
# 342976.90625 0.0
# gaussian noise
# 0.0 %
# 143088.359375 0.0
# gaussian blur
# Random crop along z-axis
# 99.94460854078095 %
# 5898.16162109375 27.63102149963379
# gaussian noise
# 0.008450704225352112 %
# 344660.0 0.0
# gaussian blur
# gaussian noise
# 0.0 %
# 196323.78125 0.0
# 0.10542196048494103 %
# 318872.5 0.0
# 0.0 %
# 75748.8359375 0.0
# 0.0 %
# 287355.84375 0.0
# elastic deform
# gaussian blur
# gaussian noise
# 99.96400968804818 %
# 5965.2568359375 27.63102149963379
# Validation Epoch: 14 	 Loss: 174700.714502	 acc: 80.000000%	 dice: 28.110426%
# -------------------------------------------------------
# --- 924.1645753383636 seconds ---
# gaussian noise
# Random crop along z-axis
# 75.20259063265145 %
# 76792.328125 1.3373820781707764
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 40.83965462998567 %
# 20693.796875 0.7930467128753662
# gaussian blur
# 45.10404789053592 %
# 17760.353515625 1.1383548974990845
# gaussian blur
# gaussian noise
# 59.706683059629405 %
# 21020.294921875 0.24112088978290558
# elastic deform
# gaussian noise
# 81.11268441967752 %
# 18285.302734375 0.15437071025371552
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 99.69410593725286 %
# 10710.0966796875 0.4835978150367737
# elastic deform
# gaussian blur
# gaussian noise
# 66.77871148459383 %
# 34811.6796875 0.5261396169662476
# elastic deform
# gaussian blur
# gaussian noise
# 85.14358753280543 %
# 24562.314453125 0.13012447953224182
# 85.85694506524797 %
# 18425.18359375 0.09907259047031403
# Random crop along z-axis
# 3.30999086599104 %
# 15591.447265625 1.0117368698120117
# gaussian noise
# 63.02061146246355 %
# 20384.66796875 0.15404559671878815
# gaussian noise
# Random crop along z-axis
# 99.46047218032713 %
# 11480.5498046875 0.3352748155593872
# elastic deform
# gaussian blur
# Random crop along z-axis
# 98.66187314565153 %
# 26043.380859375 0.8990737199783325
# Random crop along z-axis
# 97.91651860685862 %
# 62375.73046875 1.3683866262435913
# gaussian noise
# Random crop along z-axis
# 78.95257669178656 %
# 25108.3359375 0.3763523995876312
# elastic deform
# Random crop along z-axis
# 74.1991464838847 %
# 144134.421875 0.3577375113964081
# gaussian blur
# 51.35901219228081 %
# 23406.97265625 0.24653832614421844
# gaussian blur
# 99.71487519423754 %
# 10549.1171875 0.34544309973716736
# elastic deform
# Random crop along z-axis
# 75.86800239147236 %
# 26154.3828125 0.3699791431427002
# elastic deform
# gaussian blur
# Random crop along z-axis
# 18.944198303072422 %
# 19011.982421875 0.6441478729248047
# gaussian blur
# Random crop along z-axis
# 86.46926451188841 %
# 98203.75 0.28536438941955566
# elastic deform
# gaussian blur
# gaussian noise
# 43.66514530013288 %
# 31651.90234375 0.6347015500068665
# elastic deform
# gaussian blur
# Random crop along z-axis
# 77.99700844100691 %
# 24313.013671875 0.22105129063129425
# elastic deform
# gaussian blur
# 99.51712301528359 %
# 11200.029296875 0.6127381920814514
# elastic deform
# Random crop along z-axis
# 81.95810796093949 %
# 32210.2890625 0.22983121871948242
# elastic deform
# gaussian noise
# 71.2465065355397 %
# 21302.017578125 0.09584294259548187
# gaussian noise
# 37.819088319088316 %
# 33713.9375 0.21199554204940796
# elastic deform
# Random crop along z-axis
# 35.527519083257125 %
# 66133.9296875 0.13879609107971191
# gaussian noise
# 48.900794133961064 %
# 27323.52734375 0.3064446747303009
# elastic deform
# gaussian noise
# Random crop along z-axis
# 98.87170802322744 %
# 12313.9794921875 1.202235221862793
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 39.97012286499033 %
# 56005.109375 0.43354976177215576
# elastic deform
# gaussian blur
# 68.9829625771892 %
# 22829.427734375 0.06205645576119423
# elastic deform
# Random crop along z-axis
# 57.49269813585946 %
# 43899.1640625 0.23425598442554474
# elastic deform
# gaussian noise
# Random crop along z-axis
# 75.53225099141325 %
# 37161.4453125 0.29500794410705566
# elastic deform
# Random crop along z-axis
# 46.22431918645931 %
# 38915.48828125 0.13597509264945984
# elastic deform
# 99.14517665627733 %
# 11582.2177734375 0.8343895077705383
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 97.66428461808538 %
# 16527.765625 1.7280360460281372
# elastic deform
# gaussian noise
# 76.41993390128134 %
# 28742.890625 0.11844158917665482
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 0.0 %
# 16622.8203125 1.2408255338668823
# elastic deform
# gaussian noise
# Random crop along z-axis
# 70.84952139218304 %
# 76642.9453125 0.13198606669902802
# elastic deform
# gaussian blur
# 88.34692763377689 %
# 20433.853515625 0.2828574776649475
# gaussian blur
# Random crop along z-axis
# 99.59243804399945 %
# 11921.9755859375 1.4822752475738525
# gaussian blur
# gaussian noise
# 63.050055005500546 %
# 20641.23828125 0.5805362462997437
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 97.45130940589884 %
# 17423.263671875 1.1815335750579834
# gaussian blur
# gaussian noise
# 63.993736951983294 %
# 26406.5078125 0.1364998072385788
# gaussian noise
# 38.113040024299636 %
# 26806.65234375 0.4373254179954529
# elastic deform
# gaussian noise
# Random crop along z-axis
# 84.23718881726934 %
# 26055.06640625 0.3424496352672577
# elastic deform
# gaussian blur
# 99.28063151317602 %
# 12118.228515625 0.41811493039131165
# gaussian blur
# Random crop along z-axis
# 28.629184034796673 %
# 17741.54296875 1.2877627611160278
# elastic deform
# Random crop along z-axis
# 71.77906636780041 %
# 27272.662109375 0.3221159875392914
# Train Epoch: 15 	 Loss: 30828.912520	 acc: 74.000000%	 dice: 68.991468%
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 0.008013783707977722 %
# 198022.390625 0.004527790006250143
# gaussian blur
# Random crop along z-axis
# 0.012283126055581144 %
# 251864.109375 0.006657059770077467
# gaussian noise
# 0.053527817737780606 %
# 209691.75 8.344653679159819e-07
# gaussian blur
# 0.28573165541978235 %
# 243233.484375 0.00024983426555991173
# gaussian blur
# gaussian noise
# 0.5020031857894484 %
# 284584.28125 9.536747711536009e-07
# Random crop along z-axis
# 100.0 %
# 6062.04052734375 27.63102149963379
# elastic deform
# gaussian noise
# 0.0 %
# 71456.046875 0.00026044659898616374
# Random crop along z-axis
# 3.1323414252153485 %
# 443710.375 9.417578439752106e-06
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 0.0 %
# 242535.546875 0.009767334908246994
# elastic deform
# Random crop along z-axis
# 2.1019173587614066 %
# 150466.765625 0.0002370757720200345
# Validation Epoch: 15 	 Loss: 210165.443701	 acc: 90.000000%	 dice: 10.609582%
# -------------------------------------------------------
# --- 926.8018426895142 seconds ---
# gaussian blur
# gaussian noise
# 86.23334584349784 %
# 16829.54296875 0.1246594563126564
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 97.79034551864838 %
# 64451.15625 1.5041662454605103
# 28.285529006833944 %
# 24796.806640625 0.4497218728065491
# gaussian noise
# 99.44514235848061 %
# 10573.6240234375 0.6287514567375183
# elastic deform
# 53.5538507522168 %
# 16649.306640625 0.37430426478385925
# Random crop along z-axis
# 98.98316122698866 %
# 16278.2529296875 1.0628432035446167
# gaussian blur
# gaussian noise
# 74.7822703738066 %
# 22217.083984375 0.16606956720352173
# gaussian noise
# Random crop along z-axis
# 14.693099290581275 %
# 59353.5546875 1.1410685777664185
# elastic deform
# gaussian blur
# gaussian noise
# 81.9182497771072 %
# 19533.40625 0.36518070101737976
# 99.71530679655709 %
# 12660.4873046875 1.106734037399292
# gaussian blur
# Random crop along z-axis
# 87.83037846040331 %
# 62984.359375 0.47737038135528564
# gaussian blur
# Random crop along z-axis
# 67.1010539124291 %
# 31336.32421875 0.4588889479637146
# elastic deform
# gaussian noise
# Random crop along z-axis
# 89.69496130106059 %
# 33750.9140625 0.37119466066360474
# Random crop along z-axis
# 86.32216678545973 %
# 23495.9765625 0.7638573050498962
# elastic deform
# 66.14489653719637 %
# 16864.4375 0.307895302772522
# elastic deform
# gaussian noise
# Random crop along z-axis
# 99.59510603510805 %
# 11112.2333984375 1.0356597900390625
# gaussian blur
# 81.28412192902638 %
# 17907.53125 0.4856889247894287
# elastic deform
# gaussian blur
# gaussian noise
# 61.17085567297858 %
# 21747.978515625 0.27295708656311035
# Random crop along z-axis
# 6.161097372815083 %
# 86974.3125 0.7878657579421997
# elastic deform
# 60.21838937833478 %
# 26310.61328125 0.5888379812240601
# elastic deform
# Random crop along z-axis
# 82.73312419843329 %
# 40218.5390625 0.630659818649292
# gaussian blur
# Random crop along z-axis
# 99.16772524066731 %
# 13299.830078125 1.3325546979904175
# gaussian blur
# 46.17886682568694 %
# 21578.650390625 0.4318331778049469
# gaussian blur
# Random crop along z-axis
# 74.32558633937451 %
# 23736.6875 0.4447031617164612
# Random crop along z-axis
# 75.92677752888994 %
# 33521.71484375 0.21413062512874603
# gaussian noise
# 44.20972257571901 %
# 26366.72265625 0.3505779802799225
# elastic deform
# gaussian noise
# Random crop along z-axis
# 56.460920548451135 %
# 29339.6328125 0.34371811151504517
# elastic deform
# gaussian noise
# Random crop along z-axis
# 99.33407863277074 %
# 11638.2685546875 1.3348191976547241
# gaussian blur
# Random crop along z-axis
# 78.35838942404578 %
# 122325.984375 0.6228734254837036
# gaussian blur
# Random crop along z-axis
# 68.56556401713469 %
# 20954.08984375 0.2522079050540924
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 86.2588973338159 %
# 22012.021484375 0.23037245869636536
# elastic deform
# gaussian blur
# 44.53827738221599 %
# 58723.7578125 0.2956558167934418
# gaussian blur
# gaussian noise
# 55.12809720234587 %
# 22779.078125 0.34053805470466614
# elastic deform
# Random crop along z-axis
# 99.53478924673799 %
# 10222.0537109375 0.8235394954681396
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 67.0516865968818 %
# 30315.328125 0.12314415723085403
# elastic deform
# gaussian blur
# gaussian noise
# 41.785492870427774 %
# 26513.203125 0.27548566460609436
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 77.11888525859223 %
# 55981.125 0.12280727177858353
# elastic deform
# gaussian blur
# gaussian noise
# 5.481625099145148 %
# 24060.064453125 1.4920744895935059
# gaussian blur
# Random crop along z-axis
# 81.22219539952408 %
# 20171.19921875 0.22868773341178894
# 98.88543373534348 %
# 12347.0244140625 1.6075187921524048
# gaussian blur
# gaussian noise
# 47.387651620600515 %
# 25542.060546875 0.1896282285451889
# elastic deform
# 20.928945835760047 %
# 27768.09375 0.4358116388320923
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 70.85602855234094 %
# 47971.18359375 0.11658928543329239
# elastic deform
# gaussian blur
# gaussian noise
# 43.57126812157656 %
# 52684.6015625 0.10522259771823883
# gaussian noise
# Random crop along z-axis
# 36.94165355283864 %
# 23883.712890625 1.547414779663086
# gaussian noise
# 99.57724461751256 %
# 10127.2529296875 1.4112056493759155
# elastic deform
# gaussian blur
# gaussian noise
# 58.22688843962507 %
# 25643.927734375 0.13437104225158691
# gaussian blur
# gaussian noise
# 80.44647876013812 %
# 25238.306640625 0.329914927482605
# gaussian blur
# 56.89345632390268 %
# 18930.021484375 0.09777173399925232
# elastic deform
# gaussian noise
# 64.2395872484368 %
# 19215.00390625 0.48893803358078003
# Train Epoch: 16 	 Loss: 29979.317422	 acc: 72.000000%	 dice: 68.045173%
# gaussian noise
# 30.505494505494507 %
# 132012.875 0.0
# gaussian blur
# 99.90857833948577 %
# 5527.421875 27.63102149963379
# elastic deform
# Random crop along z-axis
# 2.1363090690821784 %
# 441594.59375 0.0
# Random crop along z-axis
# 7.0198550861014395 %
# 160543.40625 1.1920930376163597e-07
# elastic deform
# Random crop along z-axis
# 16.234171407597724 %
# 295962.625 0.0
# gaussian blur
# 0.7122718504229114 %
# 290947.34375 0.0
# gaussian blur
# 0.010476140589806714 %
# 127831.8671875 5.960466182841628e-07
# elastic deform
# gaussian blur
# gaussian noise
# 99.89718367272904 %
# 6136.83935546875 27.63102149963379
# gaussian blur
# 3.4822129217891704 %
# 334102.40625 0.0
# Random crop along z-axis
# 1.5964331943046166 %
# 156391.484375 0.0
# Validation Epoch: 16 	 Loss: 195110.612451	 acc: 80.000000%	 dice: 26.150299%
# -------------------------------------------------------
# --- 916.9472818374634 seconds ---
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 72.5424985327581 %
# 53254.5390625 1.0627650022506714
# gaussian blur
# gaussian noise
# 99.72338666527682 %
# 10540.271484375 1.6081924438476562
# gaussian blur
# gaussian noise
# 82.56361437723518 %
# 17202.275390625 0.49747514724731445
# elastic deform
# gaussian blur
# 90.13501135051177 %
# 19089.58203125 0.18497799336910248
# gaussian blur
# Random crop along z-axis
# 49.77728285077951 %
# 66046.0078125 0.39892280101776123
# elastic deform
# gaussian blur
# Random crop along z-axis
# 97.86128161407416 %
# 67049.3203125 0.7146148681640625
# gaussian blur
# Random crop along z-axis
# 80.54831819355445 %
# 20573.9375 0.34215694665908813
# gaussian noise
# 99.68983590169168 %
# 11798.490234375 1.12491774559021
# elastic deform
# gaussian blur
# gaussian noise
# 56.17079247853442 %
# 23435.49609375 0.13533546030521393
# gaussian blur
# 69.36152936400065 %
# 22750.76171875 0.2449256181716919
# elastic deform
# 56.668916964027396 %
# 22634.833984375 0.3519384264945984
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 64.47516038732586 %
# 28389.046875 0.543716311454773
# gaussian blur
# gaussian noise
# 86.45377878250511 %
# 16519.47265625 0.11361952871084213
# 99.70365222980594 %
# 9546.556640625 1.333619236946106
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 76.01772061598268 %
# 203209.609375 0.19980859756469727
# Random crop along z-axis
# 70.58674695746781 %
# 34628.0703125 0.4230760335922241
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 97.22039799337004 %
# 81147.25 1.4721933603286743
# elastic deform
# gaussian noise
# 20.932564140492744 %
# 18017.75390625 0.38661468029022217
# gaussian blur
# Random crop along z-axis
# 75.17264947528798 %
# 78019.46875 0.22495798766613007
# elastic deform
# gaussian blur
# gaussian noise
# 99.35712242700201 %
# 10625.9423828125 1.0908030271530151
# gaussian blur
# 82.30322851395742 %
# 26618.9375 0.2693757712841034
# elastic deform
# gaussian noise
# Random crop along z-axis
# 98.28466637290833 %
# 57471.83984375 0.7215654253959656
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 72.9169195904658 %
# 27538.31640625 0.3695211112499237
# Random crop along z-axis
# 79.22880624096409 %
# 21485.162109375 0.35302022099494934
# gaussian blur
# gaussian noise
# 31.644651485897 %
# 22267.21484375 0.5708776712417603
# 98.53709513937439 %
# 12981.5576171875 2.2973148822784424
# gaussian blur
# Random crop along z-axis
# 38.51070683779522 %
# 22085.6953125 0.2829294502735138
# 39.6549568696087 %
# 17900.255859375 0.31118956208229065
# elastic deform
# gaussian noise
# 82.87769604476027 %
# 35447.69140625 0.24064432084560394
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 1.097502597812 %
# 65918.453125 0.7278904914855957
# elastic deform
# gaussian blur
# gaussian noise
# Random crop along z-axis
# 55.98420603939517 %
# 27577.048828125 0.3947305977344513
# gaussian blur
# gaussian noise
# 99.29240877307475 %
# 10588.474609375 0.7831986546516418
# elastic deform
# Random crop along z-axis
# 70.42845419210548 %
# 47445.234375 1.5610308647155762
# 83.59765370410602 %
# 31403.328125 0.27953529357910156
# gaussian blur
# gaussian noise
# 85.15252054372628 %
# 32225.296875 0.13072465360164642
# elastic deform
# Random crop along z-axis
# 53.56082916041206 %
# 20985.232421875 0.4657965898513794
# elastic deform
# 34.70617261283178 %
# 29363.712890625 0.34095028042793274
# elastic deform
# gaussian blur
# gaussian noise
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-78ee138b193c> in <module>()
#     230         for i in range(train_interval):
#     231             img_patch, ins_patch, gt_patch, weight, c_label = next(iter(train_loader))
# --> 232             t_loss, t_c, t_dice = train_single(args, model, device, img_patch, ins_patch, gt_patch, weight, c_label, optimizer)
#     233             epoch_train_loss.append(t_loss)
#     234             epoch_train_dice.append(t_dice)
#
# <ipython-input-3-78ee138b193c> in train_single(args, model, device, img_patch, ins_patch, gt_patch, weight, c_label, optimizer)
#      65     #Calculate DiceCoeff
#      66     pred = torch.round(S).detach()
# ---> 67     train_dice_coef =  DiceCoeff(pred, gt_patch.detach())
#      68
#      69     print( train_dice_coef*100, '%')
#
# /content/metrics.py in DiceCoeff(pred, gt)
#      12
#      13 def DiceCoeff(pred, gt):
# ---> 14      pred = pred.to('cpu').numpy()
#      15      gt = gt.to('cpu').numpy()
#      16
#
# KeyboardInterrupt:

# %%
print("training:", len(train_loss))
print("validation:", len(test_loss))
x = list(range(1, len(train_loss)))
#plot train/validation loss versus epoch
plt.figure()
plt.title("Train/Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Total Loss")
plt.plot(x, train_loss,label="train loss")
plt.plot(x, test_loss, color='red', label="validation loss")
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

#plot train/validation loss versus epoch
plt.figure()
plt.title("Train/Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot(x, train_acc,label="train acc")
plt.plot(x, test_acc, color='red', label="validation acc")
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
